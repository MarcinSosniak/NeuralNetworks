# %%
import numpy as np
import matplotlib.pyplot as plt
# import mkl

# mkl.set_num_threads(4)
# np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def grad(v,W):
    vT = np.transpose(v)
    vW = np.matmul(v,W)
    qvW = sigmoid(vW)
    return np.matmul(vT,qvW)

def make_hidden(v,Wb):
    W = Wb[:,:-1]
    vW = np.matmul(v,W)
    qvW = sigmoid(vW)
    rands = np.random.random_sample(qvW.shape)
    return np.array(qvW > rands, dtype=np.float32)

def make_visible(h,Wb):
    W = Wb[:-1,:]
    WT = np.transpose(W)
    hWT= np.matmul(h,WT)
    qhWT = sigmoid(hWT)
    rands = np.random.random_sample(qhWT.shape)
    return np.array(qhWT > rands, dtype=np.float32)


def make_visible_obs(h,Wb):
    W = Wb[:-1,:]
    WT = np.transpose(W)
    hWT= np.matmul(h,WT)
    qhWT = sigmoid(hWT)
    return qhWT

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
#     print(minibatch[0].shape)
    hidden[:,:-1] = make_hidden(minibatch,rbm.W)
#     visible[:,:] = make_visible_obs(hidden,rbm.W)
    visible = sigmoid(hidden @ rbm.W.T[:,:-1])
    
    diff = np.abs(minibatch-append_ones(visible))
    diff2 = diff**2
#     diff2 = np.multiply(diff,diff)
    error = np.sum(diff2)/observations_count

#     raise Exception("Not implemented!")

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    positive_hidden[:,:-1] = make_hidden(positive_visible,rbm.W)
    negative_hidden[:,:-1] = positive_hidden[:,:-1]
    negative_visible[:,:-1] = make_visible(positive_hidden,rbm.W)
    
    for i in range(1,k):
        negative_hidden[:,:-1] = make_hidden(negative_visible,rbm.W)
        negative_visible[:,:-1] = make_visible(negative_hidden,rbm.W)
        
#     negative_visible[:,:-1] = make_visible_obs(negative_hidden,rbm.W)
    negative_visible[:,:-1] = make_visible(negative_hidden,rbm.W) # tutaj uzywamy probki, a nie obserwacji. bo dbn dziala lepiej

    pos_grad = grad(positive_visible,rbm.W)/observations_count

    
    neg_grad = grad(negative_visible,rbm.W)/observations_count
    
    e = rbm.learning_rate
    
    rbm.W = rbm.W + e*pos_grad - e*neg_grad

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 2.25s, reconstruction error: 32.12
# Epoch 1:	#####################################################	elapsed: 2.27s, reconstruction error: 25.87
# Epoch 2:	#####################################################	elapsed: 2.25s, reconstruction error: 22.65
# Epoch 3:	#####################################################	elapsed: 1.98s, reconstruction error: 20.62
# Epoch 4:	#####################################################	elapsed: 2.19s, reconstruction error: 19.30
# Epoch 5:	#####################################################	elapsed: 2.17s, reconstruction error: 18.17
# Epoch 6:	#####################################################	elapsed: 2.41s, reconstruction error: 17.38
# Epoch 7:	#####################################################	elapsed: 2.21s, reconstruction error: 16.65
# Epoch 8:	#####################################################	elapsed: 2.40s, reconstruction error: 16.05
# Epoch 9:	#####################################################	elapsed: 2.48s, reconstruction error: 15.82
# Epoch 10:	#####################################################	elapsed: 2.25s, reconstruction error: 15.32
# Epoch 11:	#####################################################	elapsed: 2.21s, reconstruction error: 14.98
# Epoch 12:	#####################################################	elapsed: 2.37s, reconstruction error: 14.77
# Epoch 13:	#####################################################	elapsed: 2.45s, reconstruction error: 14.52
# Epoch 14:	#####################################################	elapsed: 2.43s, reconstruction error: 14.40
# Epoch 15:	#####################################################	elapsed: 2.11s, reconstruction error: 14.21
# Epoch 16:	#####################################################	elapsed: 2.04s, reconstruction error: 13.91
# Epoch 17:	#####################################################	elapsed: 2.18s, reconstruction error: 13.71
# Epoch 18:	#####################################################	elapsed: 2.05s, reconstruction error: 13.31
# Epoch 19:	#####################################################	elapsed: 2.23s, reconstruction error: 13.29
# Epoch 20:	#####################################################	elapsed: 2.37s, reconstruction error: 13.15
# Epoch 21:	#####################################################	elapsed: 2.13s, reconstruction error: 13.10
# Epoch 22:	#####################################################	elapsed: 2.31s, reconstruction error: 12.96
# Epoch 23:	#####################################################	elapsed: 2.35s, reconstruction error: 12.85
# Epoch 24:	#####################################################	elapsed: 2.27s, reconstruction error: 12.79
# Epoch 25:	#####################################################	elapsed: 2.20s, reconstruction error: 12.62
# Epoch 26:	#####################################################	elapsed: 2.18s, reconstruction error: 12.67
# Epoch 27:	#####################################################	elapsed: 2.14s, reconstruction error: 12.37
# Epoch 28:	#####################################################	elapsed: 1.98s, reconstruction error: 12.33
# Epoch 29:	#####################################################	elapsed: 1.90s, reconstruction error: 12.35
# Epoch 30:	#####################################################	elapsed: 1.77s, reconstruction error: 11.99
# Epoch 31:	#####################################################	elapsed: 1.75s, reconstruction error: 12.06
# Epoch 32:	#####################################################	elapsed: 1.87s, reconstruction error: 12.01
# Epoch 33:	#####################################################	elapsed: 1.89s, reconstruction error: 12.11
# Epoch 34:	#####################################################	elapsed: 1.79s, reconstruction error: 11.86
# Epoch 35:	#####################################################	elapsed: 1.73s, reconstruction error: 11.82
# Epoch 36:	#####################################################	elapsed: 1.81s, reconstruction error: 11.82
# Epoch 37:	#####################################################	elapsed: 1.77s, reconstruction error: 11.79
# Epoch 38:	#####################################################	elapsed: 1.86s, reconstruction error: 11.79
# Epoch 39:	#####################################################	elapsed: 1.66s, reconstruction error: 11.77
# Epoch 40:	#####################################################	elapsed: 2.77s, reconstruction error: 11.53
# Epoch 41:	#####################################################	elapsed: 2.66s, reconstruction error: 11.59
# Epoch 42:	#####################################################	elapsed: 2.01s, reconstruction error: 11.47
# Epoch 43:	#####################################################	elapsed: 1.70s, reconstruction error: 11.74
# Epoch 44:	#####################################################	elapsed: 1.85s, reconstruction error: 11.52
# Epoch 45:	#####################################################	elapsed: 1.82s, reconstruction error: 11.52
# Epoch 46:	#####################################################	elapsed: 1.78s, reconstruction error: 11.41
# Epoch 47:	#####################################################	elapsed: 1.81s, reconstruction error: 11.34
# Epoch 48:	#####################################################	elapsed: 1.94s, reconstruction error: 11.42
# Epoch 49:	#####################################################	elapsed: 1.89s, reconstruction error: 11.36
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    error= reconstuction_error(dbn[layers_count], propagate_up(dbn,layers_count,minibatch))
    return error

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    k_hidden = propagate_up(dbn,layer_idx,minibatch)
    rbm = dbn[layer_idx]
    rbm_hidden = sample_rbm(rbm,k_hidden,steps)
    rbm_visible = propagate_down(dbn,layer_idx,rbm_hidden)
    return rbm_visible

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn,layer_idx,dataset)
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 2.28s, reconstruction error: 30.06
# Epoch 1:	#####################################################	elapsed: 1.95s, reconstruction error: 23.96
# Epoch 2:	#####################################################	elapsed: 2.30s, reconstruction error: 20.50
# Epoch 3:	#####################################################	elapsed: 2.71s, reconstruction error: 18.56
# Epoch 4:	#####################################################	elapsed: 2.73s, reconstruction error: 17.08
# Epoch 5:	#####################################################	elapsed: 2.66s, reconstruction error: 16.22
# Epoch 6:	#####################################################	elapsed: 2.67s, reconstruction error: 15.35
# Epoch 7:	#####################################################	elapsed: 2.59s, reconstruction error: 14.69
# Epoch 8:	#####################################################	elapsed: 2.44s, reconstruction error: 14.34
# Epoch 9:	#####################################################	elapsed: 1.74s, reconstruction error: 13.57
# Epoch 10:	#####################################################	elapsed: 2.31s, reconstruction error: 13.29
# Epoch 11:	#####################################################	elapsed: 1.91s, reconstruction error: 12.76
# Epoch 12:	#####################################################	elapsed: 2.22s, reconstruction error: 12.68
# Epoch 13:	#####################################################	elapsed: 2.45s, reconstruction error: 12.33
# Epoch 14:	#####################################################	elapsed: 2.72s, reconstruction error: 11.99
# Epoch 15:	#####################################################	elapsed: 2.48s, reconstruction error: 11.81
# Epoch 16:	#####################################################	elapsed: 2.47s, reconstruction error: 11.67
# Epoch 17:	#####################################################	elapsed: 2.38s, reconstruction error: 11.37
# Epoch 18:	#####################################################	elapsed: 2.25s, reconstruction error: 11.30
# Epoch 19:	#####################################################	elapsed: 2.12s, reconstruction error: 11.21
# Epoch 20:	#####################################################	elapsed: 1.94s, reconstruction error: 11.02
# Epoch 21:	#####################################################	elapsed: 1.96s, reconstruction error: 10.94
# Epoch 22:	#####################################################	elapsed: 1.70s, reconstruction error: 10.83
# Epoch 23:	#####################################################	elapsed: 2.74s, reconstruction error: 10.76
# Epoch 24:	#####################################################	elapsed: 2.52s, reconstruction error: 10.68
# Epoch 25:	#####################################################	elapsed: 2.63s, reconstruction error: 10.57
# Epoch 26:	#####################################################	elapsed: 2.62s, reconstruction error: 10.44
# Epoch 27:	#####################################################	elapsed: 2.71s, reconstruction error: 10.37
# Epoch 28:	#####################################################	elapsed: 2.68s, reconstruction error: 10.31
# Epoch 29:	#####################################################	elapsed: 2.68s, reconstruction error: 10.16
# Epoch 30:	#####################################################	elapsed: 2.52s, reconstruction error: 10.17
# Epoch 31:	#####################################################	elapsed: 2.64s, reconstruction error: 9.97
# Epoch 32:	#####################################################	elapsed: 2.54s, reconstruction error: 10.04
# Epoch 33:	#####################################################	elapsed: 2.63s, reconstruction error: 9.98
# Epoch 34:	#####################################################	elapsed: 2.60s, reconstruction error: 9.95
# Epoch 35:	#####################################################	elapsed: 2.39s, reconstruction error: 9.81
# Epoch 36:	#####################################################	elapsed: 2.43s, reconstruction error: 9.71
# Epoch 37:	#####################################################	elapsed: 2.61s, reconstruction error: 9.71
# Epoch 38:	#####################################################	elapsed: 2.62s, reconstruction error: 9.69
# Epoch 39:	#####################################################	elapsed: 2.59s, reconstruction error: 9.65
# Epoch 40:	#####################################################	elapsed: 3.03s, reconstruction error: 9.61
# Epoch 41:	#####################################################	elapsed: 3.68s, reconstruction error: 9.79
# Epoch 42:	#####################################################	elapsed: 4.40s, reconstruction error: 9.50
# Epoch 43:	#####################################################	elapsed: 4.44s, reconstruction error: 9.56
# Epoch 44:	#####################################################	elapsed: 3.68s, reconstruction error: 9.55
# Epoch 45:	#####################################################	elapsed: 3.49s, reconstruction error: 9.48
# Epoch 46:	#####################################################	elapsed: 3.57s, reconstruction error: 9.44
# Epoch 47:	#####################################################	elapsed: 3.64s, reconstruction error: 9.37
# Epoch 48:	#####################################################	elapsed: 3.57s, reconstruction error: 9.17
# Epoch 49:	#####################################################	elapsed: 3.49s, reconstruction error: 9.36
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 1.49s, reconstruction error: 17.94
# Epoch 1:	#####################################################	elapsed: 1.58s, reconstruction error: 13.90
# Epoch 2:	#####################################################	elapsed: 1.49s, reconstruction error: 11.45
# Epoch 3:	#####################################################	elapsed: 1.47s, reconstruction error: 9.86
# Epoch 4:	#####################################################	elapsed: 1.52s, reconstruction error: 9.10
# Epoch 5:	#####################################################	elapsed: 1.55s, reconstruction error: 8.29
# Epoch 6:	#####################################################	elapsed: 1.50s, reconstruction error: 7.97
# Epoch 7:	#####################################################	elapsed: 1.51s, reconstruction error: 7.39
# Epoch 8:	#####################################################	elapsed: 1.66s, reconstruction error: 7.08
# Epoch 9:	#####################################################	elapsed: 1.65s, reconstruction error: 6.91
# Epoch 10:	#####################################################	elapsed: 2.12s, reconstruction error: 6.52
# Epoch 11:	#####################################################	elapsed: 2.53s, reconstruction error: 6.37
# Epoch 12:	#####################################################	elapsed: 1.14s, reconstruction error: 6.26
# Epoch 13:	#####################################################	elapsed: 1.11s, reconstruction error: 6.01
# Epoch 14:	#####################################################	elapsed: 1.09s, reconstruction error: 5.96
# Epoch 15:	#####################################################	elapsed: 1.11s, reconstruction error: 5.89
# Epoch 16:	#####################################################	elapsed: 1.11s, reconstruction error: 5.70
# Epoch 17:	#####################################################	elapsed: 1.05s, reconstruction error: 5.57
# Epoch 18:	#####################################################	elapsed: 1.05s, reconstruction error: 5.49
# Epoch 19:	#####################################################	elapsed: 1.12s, reconstruction error: 5.35
# Epoch 20:	#####################################################	elapsed: 1.05s, reconstruction error: 5.43
# Epoch 21:	#####################################################	elapsed: 1.11s, reconstruction error: 5.28
# Epoch 22:	#####################################################	elapsed: 1.04s, reconstruction error: 5.14
# Epoch 23:	#####################################################	elapsed: 1.12s, reconstruction error: 5.18
# Epoch 24:	#####################################################	elapsed: 1.13s, reconstruction error: 5.14
# Epoch 25:	#####################################################	elapsed: 1.12s, reconstruction error: 5.00
# Epoch 26:	#####################################################	elapsed: 1.08s, reconstruction error: 4.98
# Epoch 27:	#####################################################	elapsed: 1.06s, reconstruction error: 4.94
# Epoch 28:	#####################################################	elapsed: 1.16s, reconstruction error: 4.98
# Epoch 29:	#####################################################	elapsed: 1.11s, reconstruction error: 4.93
# Epoch 30:	#####################################################	elapsed: 1.14s, reconstruction error: 4.87
# Epoch 31:	#####################################################	elapsed: 1.00s, reconstruction error: 4.80
# Epoch 32:	#####################################################	elapsed: 0.96s, reconstruction error: 4.84
# Epoch 33:	#####################################################	elapsed: 0.94s, reconstruction error: 4.82
# Epoch 34:	#####################################################	elapsed: 0.97s, reconstruction error: 4.76
# Epoch 35:	#####################################################	elapsed: 1.01s, reconstruction error: 4.76
# Epoch 36:	#####################################################	elapsed: 1.09s, reconstruction error: 4.62
# Epoch 37:	#####################################################	elapsed: 1.22s, reconstruction error: 4.77
# Epoch 38:	#####################################################	elapsed: 1.12s, reconstruction error: 4.71
# Epoch 39:	#####################################################	elapsed: 1.43s, reconstruction error: 4.58
# Epoch 40:	#####################################################	elapsed: 1.54s, reconstruction error: 4.71
# Epoch 41:	#####################################################	elapsed: 1.14s, reconstruction error: 4.64
# Epoch 42:	#####################################################	elapsed: 1.40s, reconstruction error: 4.52
# Epoch 43:	#####################################################	elapsed: 1.34s, reconstruction error: 4.48
# Epoch 44:	#####################################################	elapsed: 1.04s, reconstruction error: 4.47
# Epoch 45:	#####################################################	elapsed: 1.25s, reconstruction error: 4.40
# Epoch 46:	#####################################################	elapsed: 1.38s, reconstruction error: 4.57
# Epoch 47:	#####################################################	elapsed: 1.28s, reconstruction error: 4.50
# Epoch 48:	#####################################################	elapsed: 1.54s, reconstruction error: 4.47
# Epoch 49:	#####################################################	elapsed: 1.49s, reconstruction error: 4.46
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 1.76s, reconstruction error: 13.00
# Epoch 1:	#####################################################	elapsed: 1.73s, reconstruction error: 9.79
# Epoch 2:	#####################################################	elapsed: 1.57s, reconstruction error: 7.77
# Epoch 3:	#####################################################	elapsed: 1.46s, reconstruction error: 6.71
# Epoch 4:	#####################################################	elapsed: 1.43s, reconstruction error: 5.95
# Epoch 5:	#####################################################	elapsed: 1.39s, reconstruction error: 5.56
# Epoch 6:	#####################################################	elapsed: 1.43s, reconstruction error: 5.15
# Epoch 7:	#####################################################	elapsed: 1.39s, reconstruction error: 4.93
# Epoch 8:	#####################################################	elapsed: 1.67s, reconstruction error: 4.69
# Epoch 9:	#####################################################	elapsed: 1.53s, reconstruction error: 4.42
# Epoch 10:	#####################################################	elapsed: 1.44s, reconstruction error: 4.29
# Epoch 11:	#####################################################	elapsed: 1.49s, reconstruction error: 4.22
# Epoch 12:	#####################################################	elapsed: 1.53s, reconstruction error: 4.20
# Epoch 13:	#####################################################	elapsed: 1.55s, reconstruction error: 4.08
# Epoch 14:	#####################################################	elapsed: 1.54s, reconstruction error: 4.04
# Epoch 15:	#####################################################	elapsed: 1.55s, reconstruction error: 3.82
# Epoch 16:	#####################################################	elapsed: 1.63s, reconstruction error: 3.91
# Epoch 17:	#####################################################	elapsed: 1.48s, reconstruction error: 3.70
# Epoch 18:	#####################################################	elapsed: 1.35s, reconstruction error: 3.62
# Epoch 19:	#####################################################	elapsed: 1.39s, reconstruction error: 3.67
# Epoch 20:	#####################################################	elapsed: 1.32s, reconstruction error: 3.62
# Epoch 21:	#####################################################	elapsed: 1.28s, reconstruction error: 3.53
# Epoch 22:	#####################################################	elapsed: 1.34s, reconstruction error: 3.63
# Epoch 23:	#####################################################	elapsed: 1.43s, reconstruction error: 3.61
# Epoch 24:	#####################################################	elapsed: 1.32s, reconstruction error: 3.47
# Epoch 25:	#####################################################	elapsed: 1.31s, reconstruction error: 3.50
# Epoch 26:	#####################################################	elapsed: 1.35s, reconstruction error: 3.38
# Epoch 27:	#####################################################	elapsed: 1.32s, reconstruction error: 3.38
# Epoch 28:	#####################################################	elapsed: 1.31s, reconstruction error: 3.39
# Epoch 29:	#####################################################	elapsed: 1.25s, reconstruction error: 3.40
# Epoch 30:	#####################################################	elapsed: 1.31s, reconstruction error: 3.23
# Epoch 31:	#####################################################	elapsed: 1.51s, reconstruction error: 3.26
# Epoch 32:	#####################################################	elapsed: 1.42s, reconstruction error: 3.25
# Epoch 33:	#####################################################	elapsed: 1.45s, reconstruction error: 3.32
# Epoch 34:	#####################################################	elapsed: 1.98s, reconstruction error: 3.26
# Epoch 35:	#####################################################	elapsed: 1.78s, reconstruction error: 3.22
# Epoch 36:	#####################################################	elapsed: 2.06s, reconstruction error: 3.26
# Epoch 37:	#####################################################	elapsed: 1.48s, reconstruction error: 3.30
# Epoch 38:	#####################################################	elapsed: 2.75s, reconstruction error: 3.20
# Epoch 39:	#####################################################	elapsed: 2.04s, reconstruction error: 3.24
# Epoch 40:	#####################################################	elapsed: 2.00s, reconstruction error: 3.09
# Epoch 41:	#####################################################	elapsed: 4.40s, reconstruction error: 3.18
# Epoch 42:	#####################################################	elapsed: 3.15s, reconstruction error: 3.23
# Epoch 43:	#####################################################	elapsed: 2.81s, reconstruction error: 3.16
# Epoch 44:	#####################################################	elapsed: 3.59s, reconstruction error: 3.19
# Epoch 45:	#####################################################	elapsed: 3.02s, reconstruction error: 3.22
# Epoch 46:	#####################################################	elapsed: 3.37s, reconstruction error: 3.25
# Epoch 47:	#####################################################	elapsed: 4.50s, reconstruction error: 3.13
# Epoch 48:	#####################################################	elapsed: 2.95s, reconstruction error: 3.20
# Epoch 49:	#####################################################	elapsed: 3.22s, reconstruction error: 3.13
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
