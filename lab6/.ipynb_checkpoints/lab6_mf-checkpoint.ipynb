# %%
import numpy as np
import matplotlib.pyplot as plt
# import mkl

# mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Backpropagation algorithm

# %%
def sigmoid(batch):
    return 1.0 / (1.0 + np.exp(-batch))

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Softmax activation
#
# Implement the softmax activation function. Remember that naive sotmax implementation is numerically unstable: the numerator and the denominator may overflow. Make sure that your implementation has no overflow issues.

# %%
def softmax(batch):
    mx = np.max(batch,axis=1,keepdims=True)
    numerator = np.exp(batch - mx)
    denominator = np.sum(numerator,axis=1,keepdims=True)
    return numerator/denominator

# %% [markdown]
# ### Forward pass
#
# Calculate the total input to the neurons. Then calculate the activations (remember to add *ones* as the last column). Store the result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.

# %%
def forward_pass(mlp, batch, compute_derivatives):
    #compute_derivatives True if we train model
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation
#
# Fist, we need to calculate the deltas in `prev_layer`. To calculate them we use:
#  - deltas and weights from `layer`,
#  - derivatives of the activation function from `prev_layer`.
#
# Once *deltas* are calculated, we can use them to compute gradients.

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations            
            prev_layer.deltas = layer.deltas @ layer.W[:-1,:].T *  prev_layer.d_activations
        else:
            visible = batch
    
        layer.M = layer.momentum * layer.M - layer.learning_rate*(visible.T @ layer.deltas)/observations_count
        layer.W += layer.M

# %% [markdown]
# ### MLP training
#
# In order to start the back propagation procedure, we need to compute *deltas* in the output layer (that is $\Delta^{\left(y\right)}$). Use network output (from the forward pass) and target labels (stored in `batch_labels`) to calculate the *deltas*. Remember that the output layer is a softmax and that we minimize cross-entropy cost.

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
#         raise Exception("Delta in the sofmax layer is unimplemented!")
        mlp[-1].deltas = y-batch_labels # or batched_labels?
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %% [markdown]
# # MNIST digits classification

# %%
def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def run_training(mlp, train_set, train_labels,
                 validation_set, validation_labels,
                 batch_size, epochs_count):
    
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")

        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %%
def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1, :].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %%
import time

DATASET_SIZE = 60000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 150

LEARNING_RATE = 0.1
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.9

mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, MOMENTUM),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM)
]

draw_layer_filters(mlp[0])

run_training(mlp,
             mnist_train_images, mnist_train_labels,
             mnist_test_images, mnist_test_labels,
             BATCH_SIZE, EPOCHS_COUNT)

draw_layer_filters(mlp[0])
# Out:
# Epoch 1:	#####################################################	elapsed: 4.09s, accuracy: 36.50
# Epoch 2:	#####################################################	elapsed: 3.99s, accuracy: 84.09
# Epoch 3:	#####################################################	elapsed: 3.85s, accuracy: 90.89
# Epoch 4:	#####################################################	elapsed: 4.07s, accuracy: 93.16
# Epoch 5:	#####################################################	elapsed: 3.98s, accuracy: 94.47
# Epoch 6:	#####################################################	elapsed: 4.33s, accuracy: 95.16
# Epoch 7:	#####################################################	elapsed: 4.21s, accuracy: 95.63
# Epoch 8:	#####################################################	elapsed: 3.89s, accuracy: 96.10
# Epoch 9:	#####################################################	elapsed: 4.03s, accuracy: 96.39
# Epoch 10:	#####################################################	elapsed: 4.00s, accuracy: 96.45
# Epoch 11:	#####################################################	elapsed: 3.89s, accuracy: 96.52
# Epoch 12:	#####################################################	elapsed: 3.89s, accuracy: 96.60
# Epoch 13:	#####################################################	elapsed: 3.98s, accuracy: 96.80
# Epoch 14:	#####################################################	elapsed: 3.87s, accuracy: 97.08
# Epoch 15:	#####################################################	elapsed: 3.99s, accuracy: 97.17
# Epoch 16:	#####################################################	elapsed: 3.94s, accuracy: 97.23
# Epoch 17:	#####################################################	elapsed: 3.91s, accuracy: 97.28
# Epoch 18:	#####################################################	elapsed: 4.00s, accuracy: 97.26
# Epoch 19:	#####################################################	elapsed: 3.84s, accuracy: 97.32
# Epoch 20:	#####################################################	elapsed: 3.79s, accuracy: 97.38
# Epoch 21:	#####################################################	elapsed: 3.80s, accuracy: 97.42
# Epoch 22:	#####################################################	elapsed: 3.76s, accuracy: 97.47
# Epoch 23:	#####################################################	elapsed: 3.76s, accuracy: 97.38
# Epoch 24:	#####################################################	elapsed: 3.75s, accuracy: 97.36
# Epoch 25:	#####################################################	elapsed: 3.81s, accuracy: 97.38
# Epoch 26:	#####################################################	elapsed: 3.82s, accuracy: 97.54
# Epoch 27:	#####################################################	elapsed: 3.75s, accuracy: 97.71
# Epoch 28:	#####################################################	elapsed: 3.66s, accuracy: 97.47
# Epoch 29:	#####################################################	elapsed: 3.77s, accuracy: 97.06
# Epoch 30:	#####################################################	elapsed: 3.65s, accuracy: 97.20
# Epoch 31:	#####################################################	elapsed: 3.67s, accuracy: 97.83
# Epoch 32:	#####################################################	elapsed: 4.22s, accuracy: 98.00
# Epoch 33:	#####################################################	elapsed: 3.70s, accuracy: 98.06
# Epoch 34:	#####################################################	elapsed: 3.64s, accuracy: 98.00
# Epoch 35:	#####################################################	elapsed: 3.94s, accuracy: 97.91
# Epoch 36:	#####################################################	elapsed: 3.68s, accuracy: 97.93
# Epoch 37:	#####################################################	elapsed: 3.74s, accuracy: 97.96
# Epoch 38:	#####################################################	elapsed: 3.74s, accuracy: 97.98
# Epoch 39:	#####################################################	elapsed: 3.88s, accuracy: 98.02
# Epoch 40:	#####################################################	elapsed: 3.85s, accuracy: 98.05
# Epoch 41:	#####################################################	elapsed: 3.79s, accuracy: 98.10
# Epoch 42:	#####################################################	elapsed: 3.70s, accuracy: 98.14
# Epoch 43:	#####################################################	elapsed: 3.63s, accuracy: 98.12
# Epoch 44:	#####################################################	elapsed: 3.71s, accuracy: 98.10
# Epoch 45:	#####################################################	elapsed: 3.63s, accuracy: 98.07
# Epoch 46:	#####################################################	elapsed: 3.58s, accuracy: 98.07
# Epoch 47:	#####################################################	elapsed: 3.63s, accuracy: 98.04
# Epoch 48:	#####################################################	elapsed: 3.70s, accuracy: 98.05
# Epoch 49:	#####################################################	elapsed: 3.77s, accuracy: 98.03
# Epoch 50:	#####################################################	elapsed: 3.77s, accuracy: 98.03
# Epoch 51:	#####################################################	elapsed: 3.83s, accuracy: 98.01
# Epoch 52:	#####################################################	elapsed: 3.75s, accuracy: 98.02
# Epoch 53:	#####################################################	elapsed: 3.77s, accuracy: 98.02
# Epoch 54:	#####################################################	elapsed: 3.81s, accuracy: 98.00
# Epoch 55:	#####################################################	elapsed: 3.79s, accuracy: 98.01
# Epoch 56:	#####################################################	elapsed: 3.78s, accuracy: 98.03
# Epoch 57:	#####################################################	elapsed: 3.70s, accuracy: 98.06
# Epoch 58:	#####################################################	elapsed: 3.79s, accuracy: 98.07
# Epoch 59:	#####################################################	elapsed: 3.86s, accuracy: 98.07
# Epoch 60:	#####################################################	elapsed: 3.76s, accuracy: 98.09
# Epoch 61:	#####################################################	elapsed: 3.80s, accuracy: 98.07
# Epoch 62:	#####################################################	elapsed: 3.79s, accuracy: 98.07
# Epoch 63:	#####################################################	elapsed: 3.74s, accuracy: 98.08
# Epoch 64:	#####################################################	elapsed: 3.80s, accuracy: 98.05
# Epoch 65:	#####################################################	elapsed: 4.40s, accuracy: 98.06
# Epoch 66:	#####################################################	elapsed: 4.46s, accuracy: 98.06
# Epoch 67:	#####################################################	elapsed: 3.91s, accuracy: 98.07
# Epoch 68:	#####################################################	elapsed: 3.90s, accuracy: 98.07
# Epoch 69:	#####################################################	elapsed: 3.88s, accuracy: 98.06
# Epoch 70:	#####################################################	elapsed: 3.94s, accuracy: 98.06
# Epoch 71:	#####################################################	elapsed: 3.90s, accuracy: 98.06
# Epoch 72:	#####################################################	elapsed: 3.99s, accuracy: 98.05
# Epoch 73:	#####################################################	elapsed: 3.74s, accuracy: 98.06
# Epoch 74:	#####################################################	elapsed: 3.82s, accuracy: 98.06
# Epoch 75:	#####################################################	elapsed: 3.77s, accuracy: 98.07
# Epoch 76:	#####################################################	elapsed: 3.70s, accuracy: 98.07
# Epoch 77:	#####################################################	elapsed: 3.87s, accuracy: 98.07
# Epoch 78:	#####################################################	elapsed: 3.79s, accuracy: 98.07
# Epoch 79:	#####################################################	elapsed: 3.79s, accuracy: 98.07
# Epoch 80:	#####################################################	elapsed: 3.85s, accuracy: 98.06
# Epoch 81:	#####################################################	elapsed: 3.72s, accuracy: 98.06
# Epoch 82:	#####################################################	elapsed: 3.69s, accuracy: 98.06
# Epoch 83:	#####################################################	elapsed: 3.71s, accuracy: 98.06
# Epoch 84:	#####################################################	elapsed: 4.59s, accuracy: 98.06
# Epoch 85:	#####################################################	elapsed: 4.38s, accuracy: 98.06
# Epoch 86:	#####################################################	elapsed: 4.04s, accuracy: 98.06
# Epoch 87:	#####################################################	elapsed: 3.90s, accuracy: 98.06
# Epoch 88:	#####################################################	elapsed: 3.84s, accuracy: 98.06
# Epoch 89:	#####################################################	elapsed: 3.80s, accuracy: 98.07
# Epoch 90:	#####################################################	elapsed: 3.80s, accuracy: 98.07
# Epoch 91:	#####################################################	elapsed: 3.90s, accuracy: 98.07
# Epoch 92:	#####################################################	elapsed: 4.51s, accuracy: 98.07
# Epoch 93:	#####################################################	elapsed: 4.61s, accuracy: 98.07
# Epoch 94:	#####################################################	elapsed: 3.97s, accuracy: 98.08
# Epoch 95:	#####################################################	elapsed: 3.99s, accuracy: 98.08
# Epoch 96:	#####################################################	elapsed: 3.85s, accuracy: 98.08
# Epoch 97:	#####################################################	elapsed: 4.02s, accuracy: 98.08
# Epoch 98:	#####################################################	elapsed: 4.02s, accuracy: 98.08
# Epoch 99:	#####################################################	elapsed: 3.92s, accuracy: 98.08
# Epoch 100:	#####################################################	elapsed: 3.77s, accuracy: 98.09
# Epoch 101:	#####################################################	elapsed: 4.47s, accuracy: 98.09
# Epoch 102:	#####################################################	elapsed: 4.13s, accuracy: 98.09
# Epoch 103:	#####################################################	elapsed: 3.86s, accuracy: 98.09
# Epoch 104:	#####################################################	elapsed: 4.00s, accuracy: 98.09
# Epoch 105:	#####################################################	elapsed: 3.92s, accuracy: 98.09
# Epoch 106:	#####################################################	elapsed: 4.73s, accuracy: 98.09
# Epoch 107:	#####################################################	elapsed: 4.42s, accuracy: 98.09
# Epoch 108:	#####################################################	elapsed: 4.00s, accuracy: 98.09
# Epoch 109:	#####################################################	elapsed: 3.74s, accuracy: 98.09
# Epoch 110:	#####################################################	elapsed: 4.10s, accuracy: 98.09
# Epoch 111:	#####################################################	elapsed: 4.10s, accuracy: 98.09
# Epoch 112:	#####################################################	elapsed: 4.26s, accuracy: 98.10
# Epoch 113:	#####################################################	elapsed: 3.80s, accuracy: 98.10
# Epoch 114:	#####################################################	elapsed: 3.75s, accuracy: 98.10
# Epoch 115:	#####################################################	elapsed: 3.92s, accuracy: 98.10
# Epoch 116:	#####################################################	elapsed: 3.78s, accuracy: 98.10
# Epoch 117:	#####################################################	elapsed: 3.74s, accuracy: 98.09
# Epoch 118:	#####################################################	elapsed: 3.67s, accuracy: 98.09
# Epoch 119:	#####################################################	elapsed: 3.74s, accuracy: 98.10
# Epoch 120:	#####################################################	elapsed: 3.68s, accuracy: 98.10
# Epoch 121:	#####################################################	elapsed: 3.69s, accuracy: 98.10
# Epoch 122:	#####################################################	elapsed: 3.60s, accuracy: 98.10
# Epoch 123:	#####################################################	elapsed: 3.79s, accuracy: 98.10
# Epoch 124:	#####################################################	elapsed: 3.76s, accuracy: 98.10
# Epoch 125:	#####################################################	elapsed: 3.88s, accuracy: 98.10
# Epoch 126:	#####################################################	elapsed: 3.77s, accuracy: 98.10
# Epoch 127:	#####################################################	elapsed: 3.69s, accuracy: 98.10
# Epoch 128:	#####################################################	elapsed: 3.81s, accuracy: 98.09
# Epoch 129:	#####################################################	elapsed: 3.70s, accuracy: 98.08
# Epoch 130:	#####################################################	elapsed: 3.65s, accuracy: 98.08
# Epoch 131:	#####################################################	elapsed: 3.84s, accuracy: 98.08
# Epoch 132:	#####################################################	elapsed: 3.63s, accuracy: 98.08
# Epoch 133:	#####################################################	elapsed: 3.69s, accuracy: 98.08
# Epoch 134:	#####################################################	elapsed: 3.71s, accuracy: 98.08
# Epoch 135:	#####################################################	elapsed: 3.75s, accuracy: 98.08
# Epoch 136:	#####################################################	elapsed: 3.64s, accuracy: 98.08
# Epoch 137:	#####################################################	elapsed: 4.02s, accuracy: 98.08
# Epoch 138:	#####################################################	elapsed: 3.01s, accuracy: 98.08
# Epoch 139:	#####################################################	elapsed: 2.98s, accuracy: 98.08
# Epoch 140:	#####################################################	elapsed: 2.87s, accuracy: 98.08
# Epoch 141:	#####################################################	elapsed: 2.88s, accuracy: 98.08
# Epoch 142:	#####################################################	elapsed: 2.88s, accuracy: 98.08
# Epoch 143:	#####################################################	elapsed: 2.92s, accuracy: 98.08
# Epoch 144:	#####################################################	elapsed: 3.32s, accuracy: 98.09
# Epoch 145:	#####################################################	elapsed: 2.92s, accuracy: 98.09
# Epoch 146:	#####################################################	elapsed: 2.90s, accuracy: 98.09
# Epoch 147:	#####################################################	elapsed: 2.97s, accuracy: 98.08
# Epoch 148:	#####################################################	elapsed: 2.90s, accuracy: 98.08
# Epoch 149:	#####################################################	elapsed: 2.94s, accuracy: 98.08
# Epoch 150:	#####################################################	elapsed: 2.91s, accuracy: 98.08
# Training finished!
