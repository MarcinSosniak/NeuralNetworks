# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    max_vector = batch.max(axis = 1)
    max_vector_m = as_matrix(max_vector)
    batch_normalised = batch - max_vector_m
    sum_e_pow_vector_as_matrix = as_matrix(np.sum(np.exp(batch_normalised),axis = 1)) 
    p_m = np.exp(batch_normalised)
    p_m = p_m/sum_e_pow_vector_as_matrix
    return p_m

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    if stochastic:
        #return np.maximum(0,batch + as_matrix(np.random.normal(0,np.var(batch,axis =1))))
        return np.maximum(0,batch + np.random.normal(0,sigmoid(batch)))
    else:
        return np.maximum(0,batch)

def relu_derivative(batch):
    out = np.full_like(batch, 1)
    out[batch < 0] = 0
    return out;

# %%
def limit_weights(weights, limit):
    norms= np.linalg.norm(weights,axis=0) # get norms
#     print(norms)
    norms = as_matrix(norms)
#     print(norms)
    norms = norms.T # make them nromal horizontal vector as 2 dim matrix.
#     print(norms)
    p_matrix = limit / norms # assume change on all values
#     print(p_matrix)
    p_matrix[p_matrix > 1] = 1 # if we would have to extend vector then it's norm is alright, so let's not touch it
#     print(p_matrix)
    p_matrix= np.repeat(p_matrix,weights.shape[0],axis=0) # expand vector to full matrix using p[i,j] = p[k,j] for any 0<=k,i <n
#     print("P_matrix")
#     print(p_matrix)
#     print("wights")
#     print(weights)
    return weights*p_matrix
#     raise Exception("Not implemented!")
    # return ???

# %%
# A = np.array([[3,4],[6,8]])
# A=limit_weights(A,7)

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M;
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible@layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = layer.deltas@(np.transpose(layer.W[:-1,:])) *prev_layer.d_activations 
        else:
            visible = batch
        
         
        grad = np.transpose(visible)@layer.deltas /  observations_count
        layer.M = layer.momentum*layer.M - layer.learning_rate*grad
        
        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y-batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for i in range(len(dbn)): # 
        mlp[i].W = np.copy(dbn[i].W[:,:-1])

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.90s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.80s, accuracy: 31.54
# Epoch 3:	########################################	elapsed: 0.87s, accuracy: 65.26
# Epoch 4:	########################################	elapsed: 0.73s, accuracy: 74.15
# Epoch 5:	########################################	elapsed: 0.71s, accuracy: 80.37
# Epoch 6:	########################################	elapsed: 0.74s, accuracy: 89.82
# Epoch 7:	########################################	elapsed: 0.79s, accuracy: 92.10
# Epoch 8:	########################################	elapsed: 0.82s, accuracy: 92.96
# Epoch 9:	########################################	elapsed: 0.77s, accuracy: 94.55
# Epoch 10:	########################################	elapsed: 0.81s, accuracy: 94.64
# Epoch 11:	########################################	elapsed: 0.81s, accuracy: 93.70
# Epoch 12:	########################################	elapsed: 0.84s, accuracy: 95.06
# Epoch 13:	########################################	elapsed: 0.69s, accuracy: 94.24
# Epoch 14:	########################################	elapsed: 0.80s, accuracy: 94.92
# Epoch 15:	########################################	elapsed: 0.71s, accuracy: 95.39
# Epoch 16:	########################################	elapsed: 0.71s, accuracy: 95.24
# Epoch 17:	########################################	elapsed: 0.83s, accuracy: 95.03
# Epoch 18:	########################################	elapsed: 0.77s, accuracy: 95.60
# Epoch 19:	########################################	elapsed: 0.80s, accuracy: 95.87
# Epoch 20:	########################################	elapsed: 0.80s, accuracy: 96.25
# Epoch 21:	########################################	elapsed: 0.92s, accuracy: 95.98
# Epoch 22:	########################################	elapsed: 0.71s, accuracy: 96.34
# Epoch 23:	########################################	elapsed: 36.65s, accuracy: 96.44
# Epoch 24:	########################################	elapsed: 46.72s, accuracy: 96.46
# Epoch 25:	########################################	elapsed: 1.07s, accuracy: 96.53
# Epoch 26:	########################################	elapsed: 1.09s, accuracy: 96.52
# Epoch 27:	########################################	elapsed: 1.13s, accuracy: 96.52
# Epoch 28:	########################################	elapsed: 0.87s, accuracy: 96.57
# Epoch 29:	########################################	elapsed: 1.00s, accuracy: 96.57
# Epoch 30:	########################################	elapsed: 0.76s, accuracy: 96.58
# Epoch 31:	########################################	elapsed: 1.67s, accuracy: 96.59
# Epoch 32:	########################################	elapsed: 1.35s, accuracy: 96.59
# Epoch 33:	########################################	elapsed: 1.36s, accuracy: 96.60
# Epoch 34:	########################################	elapsed: 0.79s, accuracy: 96.61
# Epoch 35:	########################################	elapsed: 0.97s, accuracy: 96.61
# Epoch 36:	########################################	elapsed: 0.78s, accuracy: 96.61
# Epoch 37:	########################################	elapsed: 0.97s, accuracy: 96.61
# Epoch 38:	########################################	elapsed: 0.90s, accuracy: 96.61
# Epoch 39:	########################################	elapsed: 0.91s, accuracy: 96.62
# Epoch 40:	########################################	elapsed: 0.93s, accuracy: 96.62
# Epoch 41:	########################################	elapsed: 1.31s, accuracy: 96.62
# Epoch 42:	########################################	elapsed: 2.05s, accuracy: 96.61
# Epoch 43:	########################################	elapsed: 0.96s, accuracy: 96.61
# Epoch 44:	########################################	elapsed: 1.22s, accuracy: 96.61
# Epoch 45:	########################################	elapsed: 1.08s, accuracy: 96.62
# Epoch 46:	########################################	elapsed: 0.88s, accuracy: 96.62
# Epoch 47:	########################################	elapsed: 0.88s, accuracy: 96.62
# Epoch 48:	########################################	elapsed: 0.71s, accuracy: 96.61
# Epoch 49:	########################################	elapsed: 0.83s, accuracy: 96.62
# Epoch 50:	########################################	elapsed: 0.74s, accuracy: 96.62
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.77
# 	layer 2: 1.00
# 	layer 3: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.59s, reconstruction error: 76.49
# Epoch 2:	########################################	elapsed: 1.13s, reconstruction error: 55.18
# Epoch 3:	########################################	elapsed: 1.12s, reconstruction error: 43.02
# Epoch 4:	########################################	elapsed: 1.46s, reconstruction error: 36.62
# Epoch 5:	########################################	elapsed: 1.68s, reconstruction error: 32.75
# Epoch 6:	########################################	elapsed: 1.36s, reconstruction error: 24.85
# Epoch 7:	########################################	elapsed: 1.34s, reconstruction error: 20.77
# Epoch 8:	########################################	elapsed: 1.43s, reconstruction error: 18.39
# Epoch 9:	########################################	elapsed: 1.59s, reconstruction error: 16.65
# Epoch 10:	########################################	elapsed: 1.30s, reconstruction error: 15.35
# Epoch 11:	########################################	elapsed: 1.40s, reconstruction error: 14.42
# Epoch 12:	########################################	elapsed: 1.32s, reconstruction error: 13.49
# Epoch 13:	########################################	elapsed: 1.35s, reconstruction error: 12.79
# Epoch 14:	########################################	elapsed: 1.36s, reconstruction error: 12.12
# Epoch 15:	########################################	elapsed: 1.35s, reconstruction error: 11.51
# Epoch 16:	########################################	elapsed: 1.42s, reconstruction error: 11.07
# Epoch 17:	########################################	elapsed: 1.46s, reconstruction error: 10.77
# Epoch 18:	########################################	elapsed: 1.73s, reconstruction error: 10.23
# Epoch 19:	########################################	elapsed: 1.71s, reconstruction error: 9.99
# Epoch 20:	########################################	elapsed: 1.47s, reconstruction error: 9.81
# Epoch 21:	########################################	elapsed: 1.42s, reconstruction error: 9.46
# Epoch 22:	########################################	elapsed: 1.29s, reconstruction error: 9.19
# Epoch 23:	########################################	elapsed: 1.32s, reconstruction error: 9.10
# Epoch 24:	########################################	elapsed: 1.27s, reconstruction error: 8.97
# Epoch 25:	########################################	elapsed: 1.77s, reconstruction error: 8.89
# Epoch 26:	########################################	elapsed: 1.46s, reconstruction error: 8.70
# Epoch 27:	########################################	elapsed: 1.70s, reconstruction error: 8.54
# Epoch 28:	########################################	elapsed: 1.46s, reconstruction error: 8.48
# Epoch 29:	########################################	elapsed: 1.75s, reconstruction error: 8.41
# Epoch 30:	########################################	elapsed: 1.24s, reconstruction error: 8.30
# Epoch 31:	########################################	elapsed: 1.32s, reconstruction error: 8.18
# Epoch 32:	########################################	elapsed: 1.31s, reconstruction error: 8.21
# Epoch 33:	########################################	elapsed: 1.23s, reconstruction error: 8.14
# Epoch 34:	########################################	elapsed: 1.28s, reconstruction error: 8.13
# Epoch 35:	########################################	elapsed: 1.51s, reconstruction error: 8.09
# Epoch 36:	########################################	elapsed: 1.62s, reconstruction error: 8.14
# Epoch 37:	########################################	elapsed: 1.51s, reconstruction error: 8.00
# Epoch 38:	########################################	elapsed: 1.47s, reconstruction error: 7.94
# Epoch 39:	########################################	elapsed: 1.32s, reconstruction error: 7.88
# Epoch 40:	########################################	elapsed: 1.31s, reconstruction error: 7.79
# Epoch 41:	########################################	elapsed: 1.36s, reconstruction error: 7.82
# Epoch 42:	########################################	elapsed: 1.34s, reconstruction error: 7.85
# Epoch 43:	########################################	elapsed: 1.71s, reconstruction error: 7.82
# Epoch 44:	########################################	elapsed: 1.53s, reconstruction error: 7.76
# Epoch 45:	########################################	elapsed: 1.59s, reconstruction error: 7.76
# Epoch 46:	########################################	elapsed: 1.58s, reconstruction error: 7.71
# Epoch 47:	########################################	elapsed: 1.36s, reconstruction error: 7.63
# Epoch 48:	########################################	elapsed: 1.32s, reconstruction error: 7.61
# Epoch 49:	########################################	elapsed: 1.44s, reconstruction error: 7.62
# Epoch 50:	########################################	elapsed: 1.44s, reconstruction error: 7.51
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 1.13s, reconstruction error: 19.73
# Epoch 2:	########################################	elapsed: 1.06s, reconstruction error: 17.15
# Epoch 3:	########################################	elapsed: 1.01s, reconstruction error: 14.92
# Epoch 4:	########################################	elapsed: 1.27s, reconstruction error: 13.29
# Epoch 5:	########################################	elapsed: 1.22s, reconstruction error: 12.98
# Epoch 6:	########################################	elapsed: 1.02s, reconstruction error: 12.52
# Epoch 7:	########################################	elapsed: 1.00s, reconstruction error: 10.91
# Epoch 8:	########################################	elapsed: 1.06s, reconstruction error: 10.75
# Epoch 9:	########################################	elapsed: 1.01s, reconstruction error: 11.23
# Epoch 10:	########################################	elapsed: 1.34s, reconstruction error: 10.56
# Epoch 11:	########################################	elapsed: 0.98s, reconstruction error: 9.66
# Epoch 12:	########################################	elapsed: 1.07s, reconstruction error: 9.73
# Epoch 13:	########################################	elapsed: 1.06s, reconstruction error: 10.28
# Epoch 14:	########################################	elapsed: 1.05s, reconstruction error: 10.07
# Epoch 15:	########################################	elapsed: 1.35s, reconstruction error: 8.89
# Epoch 16:	########################################	elapsed: 1.19s, reconstruction error: 9.43
# Epoch 17:	########################################	elapsed: 1.14s, reconstruction error: 9.19
# Epoch 18:	########################################	elapsed: 1.06s, reconstruction error: 9.45
# Epoch 19:	########################################	elapsed: 1.04s, reconstruction error: 9.86
# Epoch 20:	########################################	elapsed: 1.04s, reconstruction error: 9.12
# Epoch 21:	########################################	elapsed: 1.11s, reconstruction error: 8.76
# Epoch 22:	########################################	elapsed: 1.16s, reconstruction error: 8.91
# Epoch 23:	########################################	elapsed: 1.12s, reconstruction error: 8.42
# Epoch 24:	########################################	elapsed: 1.20s, reconstruction error: 8.49
# Epoch 25:	########################################	elapsed: 1.03s, reconstruction error: 9.05
# Epoch 26:	########################################	elapsed: 1.20s, reconstruction error: 8.81
# Epoch 27:	########################################	elapsed: 1.23s, reconstruction error: 8.73
# Epoch 28:	########################################	elapsed: 1.09s, reconstruction error: 8.80
# Epoch 29:	########################################	elapsed: 1.22s, reconstruction error: 8.10
# Epoch 30:	########################################	elapsed: 1.80s, reconstruction error: 8.28
# Epoch 31:	########################################	elapsed: 1.29s, reconstruction error: 8.31
# Epoch 32:	########################################	elapsed: 1.10s, reconstruction error: 8.47
# Epoch 33:	########################################	elapsed: 1.30s, reconstruction error: 8.46
# Epoch 34:	########################################	elapsed: 1.23s, reconstruction error: 8.31
# Epoch 35:	########################################	elapsed: 1.30s, reconstruction error: 8.29
# Epoch 36:	########################################	elapsed: 1.23s, reconstruction error: 8.21
# Epoch 37:	########################################	elapsed: 1.18s, reconstruction error: 8.38
# Epoch 38:	########################################	elapsed: 1.09s, reconstruction error: 7.83
# Epoch 39:	########################################	elapsed: 1.31s, reconstruction error: 8.01
# Epoch 40:	########################################	elapsed: 1.32s, reconstruction error: 8.42
# Epoch 41:	########################################	elapsed: 1.25s, reconstruction error: 8.24
# Epoch 42:	########################################	elapsed: 1.15s, reconstruction error: 8.27
# Epoch 43:	########################################	elapsed: 1.23s, reconstruction error: 7.85
# Epoch 44:	########################################	elapsed: 1.25s, reconstruction error: 8.15
# Epoch 45:	########################################	elapsed: 1.05s, reconstruction error: 7.73
# Epoch 46:	########################################	elapsed: 0.98s, reconstruction error: 8.27
# Epoch 47:	########################################	elapsed: 1.01s, reconstruction error: 7.68
# Epoch 48:	########################################	elapsed: 1.02s, reconstruction error: 7.71
# Epoch 49:	########################################	elapsed: 1.18s, reconstruction error: 8.23
# Epoch 50:	########################################	elapsed: 1.02s, reconstruction error: 7.98
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.77s, accuracy: 93.35
# Epoch 2:	########################################	elapsed: 0.74s, accuracy: 94.46
# Epoch 3:	########################################	elapsed: 1.06s, accuracy: 94.91
# Epoch 4:	########################################	elapsed: 0.79s, accuracy: 95.99
# Epoch 5:	########################################	elapsed: 0.82s, accuracy: 96.27
# Epoch 6:	########################################	elapsed: 0.73s, accuracy: 96.35
# Epoch 7:	########################################	elapsed: 0.98s, accuracy: 96.17
# Epoch 8:	########################################	elapsed: 0.91s, accuracy: 96.49
# Epoch 9:	########################################	elapsed: 0.90s, accuracy: 96.76
# Epoch 10:	########################################	elapsed: 0.95s, accuracy: 96.72
# Epoch 11:	########################################	elapsed: 1.06s, accuracy: 96.84
# Epoch 12:	########################################	elapsed: 0.93s, accuracy: 96.98
# Epoch 13:	########################################	elapsed: 0.94s, accuracy: 97.03
# Epoch 14:	########################################	elapsed: 0.93s, accuracy: 97.18
# Epoch 15:	########################################	elapsed: 0.97s, accuracy: 97.19
# Epoch 16:	########################################	elapsed: 0.80s, accuracy: 97.21
# Epoch 17:	########################################	elapsed: 0.84s, accuracy: 97.26
# Epoch 20:	########################################	elapsed: 1.12s, accuracy: 95.70
# Epoch 21:	########################################	elapsed: 1.09s, accuracy: 94.61
# Epoch 22:	########################################	elapsed: 1.05s, accuracy: 95.25
# Epoch 23:	########################################	elapsed: 1.08s, accuracy: 96.05
# Epoch 24:	########################################	elapsed: 1.09s, accuracy: 95.71
# Epoch 25:	########################################	elapsed: 1.14s, accuracy: 96.02
# Epoch 26:	########################################	elapsed: 1.15s, accuracy: 96.28
# Epoch 27:	########################################	elapsed: 1.08s, accuracy: 96.24
# Epoch 28:	########################################	elapsed: 1.10s, accuracy: 96.40
# Epoch 29:	########################################	elapsed: 1.15s, accuracy: 96.37
# Epoch 30:	########################################	elapsed: 1.15s, accuracy: 96.31
# Epoch 31:	########################################	elapsed: 1.13s, accuracy: 96.38
# Epoch 32:	########################################	elapsed: 1.15s, accuracy: 96.41
# Epoch 33:	########################################	elapsed: 1.13s, accuracy: 96.43
# Epoch 34:	########################################	elapsed: 1.11s, accuracy: 96.43
# Epoch 35:	########################################	elapsed: 1.12s, accuracy: 96.42
# Epoch 36:	########################################	elapsed: 1.15s, accuracy: 96.40
# Epoch 37:	########################################	elapsed: 1.18s, accuracy: 96.39
# Epoch 38:	########################################	elapsed: 1.13s, accuracy: 96.39
# Epoch 39:	########################################	elapsed: 1.17s, accuracy: 96.38
# Epoch 40:	########################################	elapsed: 1.16s, accuracy: 96.41
# Epoch 41:	########################################	elapsed: 1.16s, accuracy: 96.42
# Epoch 42:	########################################	elapsed: 1.14s, accuracy: 96.43
# Epoch 43:	########################################	elapsed: 1.21s, accuracy: 96.43
# Epoch 44:	########################################	elapsed: 1.14s, accuracy: 96.46
# Epoch 45:	########################################	elapsed: 1.15s, accuracy: 96.45
# Epoch 46:	########################################	elapsed: 1.17s, accuracy: 96.45
# Epoch 47:	########################################	elapsed: 1.14s, accuracy: 96.46
# Epoch 48:	########################################	elapsed: 1.18s, accuracy: 96.45
# Epoch 49:	########################################	elapsed: 1.16s, accuracy: 96.47
# Epoch 50:	########################################	elapsed: 1.17s, accuracy: 96.47
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.82
# 	layer 4: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.17s, reconstruction error: 76.16
# Epoch 2:	########################################	elapsed: 1.48s, reconstruction error: 55.14
# Epoch 3:	########################################	elapsed: 1.42s, reconstruction error: 42.69
# Epoch 4:	########################################	elapsed: 1.66s, reconstruction error: 36.31
# Epoch 5:	########################################	elapsed: 1.42s, reconstruction error: 32.54
# Epoch 6:	########################################	elapsed: 1.16s, reconstruction error: 24.57
# Epoch 7:	########################################	elapsed: 1.17s, reconstruction error: 20.69
# Epoch 8:	########################################	elapsed: 1.18s, reconstruction error: 18.37
# Epoch 9:	########################################	elapsed: 1.17s, reconstruction error: 16.64
# Epoch 10:	########################################	elapsed: 1.14s, reconstruction error: 15.37
# Epoch 11:	########################################	elapsed: 1.17s, reconstruction error: 14.57
# Epoch 12:	########################################	elapsed: 1.48s, reconstruction error: 13.49
# Epoch 13:	########################################	elapsed: 1.56s, reconstruction error: 12.93
# Epoch 14:	########################################	elapsed: 1.53s, reconstruction error: 12.15
# Epoch 15:	########################################	elapsed: 1.23s, reconstruction error: 11.57
# Epoch 16:	########################################	elapsed: 1.14s, reconstruction error: 11.11
# Epoch 17:	########################################	elapsed: 1.18s, reconstruction error: 10.71
# Epoch 18:	########################################	elapsed: 1.16s, reconstruction error: 10.37
# Epoch 19:	########################################	elapsed: 1.20s, reconstruction error: 10.01
# Epoch 20:	########################################	elapsed: 1.44s, reconstruction error: 9.77
# Epoch 21:	########################################	elapsed: 1.22s, reconstruction error: 9.55
# Epoch 22:	########################################	elapsed: 1.22s, reconstruction error: 9.46
# Epoch 23:	########################################	elapsed: 1.23s, reconstruction error: 9.27
# Epoch 24:	########################################	elapsed: 1.22s, reconstruction error: 9.10
# Epoch 25:	########################################	elapsed: 1.29s, reconstruction error: 9.00
# Epoch 26:	########################################	elapsed: 1.21s, reconstruction error: 8.83
# Epoch 27:	########################################	elapsed: 1.46s, reconstruction error: 8.77
# Epoch 28:	########################################	elapsed: 1.64s, reconstruction error: 8.62
# Epoch 29:	########################################	elapsed: 1.20s, reconstruction error: 8.58
# Epoch 30:	########################################	elapsed: 1.13s, reconstruction error: 8.46
# Epoch 31:	########################################	elapsed: 1.17s, reconstruction error: 8.41
# Epoch 32:	########################################	elapsed: 1.16s, reconstruction error: 8.32
# Epoch 33:	########################################	elapsed: 1.18s, reconstruction error: 8.22
# Epoch 34:	########################################	elapsed: 1.22s, reconstruction error: 8.17
# Epoch 35:	########################################	elapsed: 1.20s, reconstruction error: 8.17
# Epoch 36:	########################################	elapsed: 1.20s, reconstruction error: 8.08
# Epoch 37:	########################################	elapsed: 1.27s, reconstruction error: 8.04
# Epoch 38:	########################################	elapsed: 1.28s, reconstruction error: 7.98
# Epoch 39:	########################################	elapsed: 1.16s, reconstruction error: 7.89
# Epoch 40:	########################################	elapsed: 1.14s, reconstruction error: 7.82
# Epoch 41:	########################################	elapsed: 1.15s, reconstruction error: 7.88
# Epoch 42:	########################################	elapsed: 1.17s, reconstruction error: 7.85
# Epoch 43:	########################################	elapsed: 1.68s, reconstruction error: 7.85
# Epoch 44:	########################################	elapsed: 1.78s, reconstruction error: 7.83
# Epoch 45:	########################################	elapsed: 1.52s, reconstruction error: 7.82
# Epoch 46:	########################################	elapsed: 1.24s, reconstruction error: 7.76
# Epoch 47:	########################################	elapsed: 1.23s, reconstruction error: 7.62
# Epoch 48:	########################################	elapsed: 1.25s, reconstruction error: 7.67
# Epoch 49:	########################################	elapsed: 1.35s, reconstruction error: 7.65
# Epoch 50:	########################################	elapsed: 1.67s, reconstruction error: 7.68
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 1.18s, reconstruction error: 18.80
# Epoch 2:	########################################	elapsed: 1.01s, reconstruction error: 17.33
# Epoch 3:	########################################	elapsed: 1.19s, reconstruction error: 14.81
# Epoch 4:	########################################	elapsed: 1.04s, reconstruction error: 13.66
# Epoch 5:	########################################	elapsed: 1.16s, reconstruction error: 13.03
# Epoch 6:	########################################	elapsed: 1.01s, reconstruction error: 12.83
# Epoch 7:	########################################	elapsed: 0.97s, reconstruction error: 11.81
# Epoch 8:	########################################	elapsed: 1.06s, reconstruction error: 10.74
# Epoch 9:	########################################	elapsed: 1.02s, reconstruction error: 10.66
# Epoch 10:	########################################	elapsed: 0.99s, reconstruction error: 10.44
# Epoch 11:	########################################	elapsed: 0.96s, reconstruction error: 9.52
# Epoch 12:	########################################	elapsed: 1.00s, reconstruction error: 9.86
# Epoch 13:	########################################	elapsed: 0.99s, reconstruction error: 9.66
# Epoch 14:	########################################	elapsed: 1.48s, reconstruction error: 9.39
# Epoch 15:	########################################	elapsed: 1.38s, reconstruction error: 9.64
# Epoch 16:	########################################	elapsed: 1.38s, reconstruction error: 9.58
# Epoch 17:	########################################	elapsed: 1.11s, reconstruction error: 9.09
# Epoch 18:	########################################	elapsed: 1.10s, reconstruction error: 8.94
# Epoch 19:	########################################	elapsed: 1.10s, reconstruction error: 8.52
# Epoch 20:	########################################	elapsed: 1.33s, reconstruction error: 8.51
# Epoch 21:	########################################	elapsed: 1.23s, reconstruction error: 8.99
# Epoch 22:	########################################	elapsed: 1.22s, reconstruction error: 8.80
# Epoch 23:	########################################	elapsed: 1.11s, reconstruction error: 8.66
# Epoch 24:	########################################	elapsed: 1.06s, reconstruction error: 8.86
# Epoch 25:	########################################	elapsed: 1.13s, reconstruction error: 8.45
# Epoch 26:	########################################	elapsed: 1.07s, reconstruction error: 8.77
# Epoch 27:	########################################	elapsed: 1.23s, reconstruction error: 8.66
# Epoch 28:	########################################	elapsed: 1.08s, reconstruction error: 8.35
# Epoch 29:	########################################	elapsed: 0.99s, reconstruction error: 8.65
# Epoch 30:	########################################	elapsed: 0.99s, reconstruction error: 7.82
# Epoch 31:	########################################	elapsed: 0.91s, reconstruction error: 8.19
# Epoch 32:	########################################	elapsed: 1.02s, reconstruction error: 8.77
# Epoch 33:	########################################	elapsed: 1.01s, reconstruction error: 8.20
# Epoch 34:	########################################	elapsed: 1.00s, reconstruction error: 8.78
# Epoch 35:	########################################	elapsed: 1.03s, reconstruction error: 8.17
# Epoch 36:	########################################	elapsed: 0.96s, reconstruction error: 8.17
# Epoch 37:	########################################	elapsed: 0.93s, reconstruction error: 8.05
# Epoch 38:	########################################	elapsed: 0.94s, reconstruction error: 8.49
# Epoch 39:	########################################	elapsed: 0.89s, reconstruction error: 8.02
# Epoch 40:	########################################	elapsed: 0.95s, reconstruction error: 7.81
# Epoch 41:	########################################	elapsed: 0.99s, reconstruction error: 7.87
# Epoch 42:	########################################	elapsed: 0.89s, reconstruction error: 8.48
# Epoch 43:	########################################	elapsed: 0.94s, reconstruction error: 7.91
# Epoch 44:	########################################	elapsed: 0.89s, reconstruction error: 7.85
# Epoch 45:	########################################	elapsed: 0.99s, reconstruction error: 7.74
# Epoch 46:	########################################	elapsed: 1.16s, reconstruction error: 7.81
# Epoch 47:	########################################	elapsed: 0.93s, reconstruction error: 7.71
# Epoch 48:	########################################	elapsed: 0.93s, reconstruction error: 8.03
# Epoch 49:	########################################	elapsed: 1.01s, reconstruction error: 7.74
# Epoch 50:	########################################	elapsed: 0.86s, reconstruction error: 7.81
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 1.43s, reconstruction error: 5.56
# Epoch 2:	########################################	elapsed: 1.41s, reconstruction error: 5.93
# Epoch 3:	########################################	elapsed: 1.62s, reconstruction error: 5.71
# Epoch 4:	########################################	elapsed: 1.82s, reconstruction error: 5.59
# Epoch 5:	########################################	elapsed: 1.41s, reconstruction error: 5.72
# Epoch 6:	########################################	elapsed: 1.42s, reconstruction error: 5.84
# Epoch 7:	########################################	elapsed: 1.41s, reconstruction error: 5.56
# Epoch 8:	########################################	elapsed: 1.47s, reconstruction error: 5.94
# Epoch 9:	########################################	elapsed: 1.40s, reconstruction error: 5.51
# Epoch 10:	########################################	elapsed: 1.52s, reconstruction error: 4.80
# Epoch 11:	########################################	elapsed: 1.41s, reconstruction error: 5.20
# Epoch 12:	########################################	elapsed: 1.38s, reconstruction error: 5.70
# Epoch 13:	########################################	elapsed: 1.40s, reconstruction error: 4.86
# Epoch 14:	########################################	elapsed: 1.41s, reconstruction error: 5.38
# Epoch 15:	########################################	elapsed: 1.44s, reconstruction error: 5.05
# Epoch 16:	########################################	elapsed: 1.40s, reconstruction error: 5.12
# Epoch 17:	########################################	elapsed: 1.45s, reconstruction error: 4.90
# Epoch 18:	########################################	elapsed: 1.45s, reconstruction error: 5.19
# Epoch 19:	########################################	elapsed: 1.40s, reconstruction error: 5.28
# Epoch 20:	########################################	elapsed: 1.48s, reconstruction error: 5.26
# Epoch 21:	########################################	elapsed: 1.39s, reconstruction error: 4.88
# Epoch 22:	########################################	elapsed: 1.42s, reconstruction error: 4.68
# Epoch 23:	########################################	elapsed: 1.53s, reconstruction error: 5.15
# Epoch 24:	########################################	elapsed: 1.40s, reconstruction error: 5.06
# Epoch 25:	########################################	elapsed: 1.49s, reconstruction error: 4.93
# Epoch 26:	########################################	elapsed: 1.39s, reconstruction error: 4.49
# Epoch 27:	########################################	elapsed: 1.40s, reconstruction error: 4.85
# Epoch 28:	########################################	elapsed: 1.39s, reconstruction error: 4.93
# Epoch 29:	########################################	elapsed: 1.41s, reconstruction error: 5.01
# Epoch 30:	########################################	elapsed: 1.52s, reconstruction error: 4.67
# Epoch 31:	########################################	elapsed: 1.52s, reconstruction error: 5.11
# Epoch 32:	########################################	elapsed: 1.47s, reconstruction error: 4.79
# Epoch 33:	########################################	elapsed: 1.42s, reconstruction error: 4.82
# Epoch 34:	########################################	elapsed: 1.41s, reconstruction error: 4.44
# Epoch 35:	########################################	elapsed: 1.39s, reconstruction error: 4.33
# Epoch 36:	########################################	elapsed: 1.39s, reconstruction error: 4.50
# Epoch 37:	########################################	elapsed: 1.44s, reconstruction error: 4.45
# Epoch 38:	########################################	elapsed: 1.47s, reconstruction error: 4.63
# Epoch 39:	########################################	elapsed: 1.48s, reconstruction error: 4.24
# Epoch 40:	########################################	elapsed: 1.47s, reconstruction error: 4.65
# Epoch 41:	########################################	elapsed: 1.40s, reconstruction error: 4.66
# Epoch 42:	########################################	elapsed: 1.43s, reconstruction error: 4.36
# Epoch 43:	########################################	elapsed: 1.40s, reconstruction error: 4.28
# Epoch 44:	########################################	elapsed: 1.40s, reconstruction error: 4.36
# Epoch 45:	########################################	elapsed: 1.46s, reconstruction error: 4.27
# Epoch 46:	########################################	elapsed: 1.46s, reconstruction error: 4.16
# Epoch 47:	########################################	elapsed: 1.51s, reconstruction error: 4.30
# Epoch 48:	########################################	elapsed: 1.47s, reconstruction error: 4.42
# Epoch 49:	########################################	elapsed: 1.40s, reconstruction error: 4.37
# Epoch 50:	########################################	elapsed: 1.39s, reconstruction error: 4.34
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0