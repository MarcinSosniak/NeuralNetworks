# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# import mkl

# mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities, _ = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(16, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    mx = np.max(batch,axis=1,keepdims=True)
    numerator = np.exp(batch - mx)
    denominator = np.sum(numerator,axis=1,keepdims=True)
    return numerator/denominator

# %%
def relu(batch, stochastic=False):
    if stochastic:
        return np.maximum(0,batch+np.random.normal(0,sigmoid(batch)))
    else:
        return np.maximum(0,batch)
    
def relu_derivative(batch):
    out = ones(*batch.shape)
    out[batch<0] = 0
    return out

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 dropout_rate, learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
        
        self.dropout_rate = dropout_rate # 0.3  = 30%
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None
        
        self.M = zeros(self.visible_size+1, self.hidden_size)
        
    def deep_copy(self):
        copy = Layer(self.visible_size, self.hidden_size, self.activation_fun, self.d_activation_fun,
                     self.dropout_rate, self.learning_rate, self.momentum, self.weight_limit)
        copy.W = np.copy(self.W)
        copy.M = np.copy(self.M)
        return copy

# %%
def limit_weights(weights, limit):
    sum_in_vectors = np.linalg.norm(weights,axis=0)
    pj = limit/sum_in_vectors
    pj[pj > 1] = 1
    p = np.empty(weights.shape)
    p[:,:] = pj
    #przemnazamy przez nasz macierz
    return weights*p

# %% [markdown]
# ### Forward pass
#
# Calculate total input to the neurons. Then calculate activations (remember to add *ones* as the last column). Store result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.
#
# ##### Dropout
#
# If `compute_derivatives` is set to `True` and the dropout rate in the input layer is greater than 0, we need to calculate the dropout mask for the MLP input and apply it to `batch`.
#
# When calculating hidden activations in an MLP layer, check whether dropout rate in the next layer is greater then 0. If yes, then we need to apply dropout to the calculated activations (and derivatives of activations). In this case:
# * construct dropout mask for the hidden layer,
# * apply this mask to where it is needed in the hidden layer.
#
# Do **not** apply dropout to the last column in activations or input batch, as they contains fixed *ones*.

# %%
def forward_pass(mlp, batch, compute_derivatives):
    if compute_derivatives and mlp[0].dropout_rate > 0:
        batch = np.copy(batch)
#         raise Exception("Dropout in the forward pass is not implemented!")
        droput_mask = np.random.rand(batch.shape[1]) < mlp[0].dropout_rate
        
        #consider quoting
        droput_mask[-1] = False # nie powinienem usuwac biasu
        
        batch_droput_mask = np.empty(shape=batch.shape,dtype=bool)
        
        batch_droput_mask[:,:] = droput_mask
        batch[batch_droput_mask] = 0
        
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
#         raise Exception('Compute layer activations here!')
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
#             raise Exception('Remember about the derivatives of the activation function!')
            layer.d_activations = layer.d_activation_fun(z)
            
            if mlp[layer_idx+1].dropout_rate > 0:
                #ustalic ymiar tego wektora
                droput_mask = np.random.rand(mlp[layer_idx+1].visible_size+1) < mlp[layer_idx+1].dropout_rate
                droput_mask[-1] = False
                # in this case we are not affecting bias
                activations_droput_mask = np.empty(shape=[layer.activations.shape[0],layer.activations.shape[1]],dtype=bool)
                activations_droput_mask[:,:] = droput_mask

                #usuwa -> zeruje aktywacje oraz zeruje pochodne aktywacji 
                # podobno lepiej pomnozyc przez maske... ale to powinno zadzialac rownie szybko?
                layer.activations[activations_droput_mask] = 0
                layer.d_activations[activations_droput_mask[:,:-1]] = 0
#                 raise Exception("Dropout in the forward pass is not implemented!")
                #
                # apply dropout where is it needed in the hidden layer
                #
        
        visible = layer.activations
    
    return visible[:, :-1], batch

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations            
            prev_layer.deltas = layer.deltas @ layer.W[:-1,:].T *  prev_layer.d_activations
        else:
            visible = batch
        pen = 0
#         if layer.l2_penalty > 0:
#             penalty = layer.l2_penalty*layer.W[:-1,:-1]
            
        layer.M = layer.momentum * layer.M - layer.learning_rate*(visible.T @ layer.deltas)/observations_count
#         layer.M[:-1,:-1] -= penalty
        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Mean dropout network
#
# Implement the weight scalling for the network that approximates MLP outputs under dropout.

# %%
def mean_network(mlp):
    mlp = [layer.deep_copy() for layer in mlp]
    
    for layer in mlp:
        if layer.dropout_rate > 0:
            layer.W = (1-layer.dropout_rate)*layer.W
#         raise Exception("Mean dropout network is not implemented!")
    
    return mlp

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y,batch = forward_pass(mlp, batch, True)
        mlp[-1].deltas = y-batch_labels # or batched_labels?
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp:
                layer.momentum = 0.95
                layer.lr = 0.15
        elif epoch == 170:
            for layer in mlp:
                layer.momentum = 0.5
                layer.lr = 0.01
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time
        
        test_mlp = mean_network(mlp)
        
        predictions = classify(test_mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 5000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 512

BATCH_SIZE = 128
EPOCHS_COUNT = 200

LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5

# %%
from IPython.core.display import HTML

def evaluate(mlp, train_set, train_labels,
             validation_set, validation_labels,
             batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Plain MLP (no dropout)

# %%
mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.0, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

evaluate(mlp, 
         mnist_train_images, mnist_train_labels, 
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.24s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.35s, accuracy: 20.59
# Epoch 3:	########################################	elapsed: 1.43s, accuracy: 37.21
# Epoch 4:	########################################	elapsed: 1.39s, accuracy: 59.92
# Epoch 5:	########################################	elapsed: 1.21s, accuracy: 66.31
# Epoch 6:	########################################	elapsed: 1.02s, accuracy: 80.25
# Epoch 7:	########################################	elapsed: 1.00s, accuracy: 85.05
# Epoch 8:	########################################	elapsed: 1.03s, accuracy: 89.24
# Epoch 9:	########################################	elapsed: 1.00s, accuracy: 92.06
# Epoch 10:	########################################	elapsed: 0.98s, accuracy: 93.78
# Epoch 11:	########################################	elapsed: 0.99s, accuracy: 92.00
# Epoch 12:	########################################	elapsed: 1.04s, accuracy: 93.73
# Epoch 13:	########################################	elapsed: 1.06s, accuracy: 93.65
# Epoch 14:	########################################	elapsed: 0.97s, accuracy: 94.15
# Epoch 15:	########################################	elapsed: 0.97s, accuracy: 93.79
# Epoch 16:	########################################	elapsed: 0.99s, accuracy: 94.63
# Epoch 17:	########################################	elapsed: 0.98s, accuracy: 93.93
# Epoch 18:	########################################	elapsed: 1.03s, accuracy: 93.59
# Epoch 19:	########################################	elapsed: 1.03s, accuracy: 94.18
# Epoch 20:	########################################	elapsed: 1.04s, accuracy: 93.49
# Epoch 21:	########################################	elapsed: 1.04s, accuracy: 94.74
# Epoch 22:	########################################	elapsed: 1.00s, accuracy: 94.36
# Epoch 23:	########################################	elapsed: 0.97s, accuracy: 94.27
# Epoch 24:	########################################	elapsed: 0.97s, accuracy: 94.93
# Epoch 25:	########################################	elapsed: 0.98s, accuracy: 94.96
# Epoch 26:	########################################	elapsed: 0.98s, accuracy: 95.22
# Epoch 27:	########################################	elapsed: 0.97s, accuracy: 95.16
# Epoch 28:	########################################	elapsed: 0.96s, accuracy: 94.97
# Epoch 29:	########################################	elapsed: 0.98s, accuracy: 95.28
# Epoch 30:	########################################	elapsed: 0.97s, accuracy: 95.29
# Epoch 31:	########################################	elapsed: 0.97s, accuracy: 95.32
# Epoch 32:	########################################	elapsed: 0.99s, accuracy: 95.33
# Epoch 33:	########################################	elapsed: 0.97s, accuracy: 95.33
# Epoch 34:	########################################	elapsed: 0.97s, accuracy: 95.36
# Epoch 35:	########################################	elapsed: 1.03s, accuracy: 95.39
# Epoch 36:	########################################	elapsed: 0.98s, accuracy: 95.40
# Epoch 37:	########################################	elapsed: 0.97s, accuracy: 95.39
# Epoch 38:	########################################	elapsed: 0.99s, accuracy: 95.36
# Epoch 39:	########################################	elapsed: 0.97s, accuracy: 95.36
# Epoch 40:	########################################	elapsed: 0.99s, accuracy: 95.35
# Epoch 41:	########################################	elapsed: 0.99s, accuracy: 95.37
# Epoch 42:	########################################	elapsed: 1.13s, accuracy: 95.38
# Epoch 43:	########################################	elapsed: 1.00s, accuracy: 95.37
# Epoch 44:	########################################	elapsed: 0.98s, accuracy: 95.37
# Epoch 45:	########################################	elapsed: 1.01s, accuracy: 95.37
# Epoch 46:	########################################	elapsed: 1.04s, accuracy: 95.35
# Epoch 47:	########################################	elapsed: 1.03s, accuracy: 95.35
# Epoch 48:	########################################	elapsed: 1.00s, accuracy: 95.35
# Epoch 49:	########################################	elapsed: 1.06s, accuracy: 95.36
# Epoch 50:	########################################	elapsed: 1.06s, accuracy: 95.36
# Epoch 51:	########################################	elapsed: 1.02s, accuracy: 95.36
# Epoch 52:	########################################	elapsed: 1.04s, accuracy: 95.37
# Epoch 53:	########################################	elapsed: 1.00s, accuracy: 95.36
# Epoch 54:	########################################	elapsed: 1.14s, accuracy: 95.37
# Epoch 55:	########################################	elapsed: 1.15s, accuracy: 95.36
# Epoch 56:	########################################	elapsed: 1.14s, accuracy: 95.35
# Epoch 57:	########################################	elapsed: 1.26s, accuracy: 95.35
# Epoch 58:	########################################	elapsed: 1.28s, accuracy: 95.34
# Epoch 59:	########################################	elapsed: 1.07s, accuracy: 95.35
# Epoch 60:	########################################	elapsed: 1.11s, accuracy: 95.37
# Epoch 61:	########################################	elapsed: 1.20s, accuracy: 95.37
# Epoch 62:	########################################	elapsed: 1.17s, accuracy: 95.37
# Epoch 63:	########################################	elapsed: 0.99s, accuracy: 95.38
# Epoch 64:	########################################	elapsed: 1.06s, accuracy: 95.38
# Epoch 65:	########################################	elapsed: 1.04s, accuracy: 95.38
# Epoch 66:	########################################	elapsed: 1.04s, accuracy: 95.39
# Epoch 67:	########################################	elapsed: 1.06s, accuracy: 95.39
# Epoch 68:	########################################	elapsed: 1.13s, accuracy: 95.39
# Epoch 69:	########################################	elapsed: 1.17s, accuracy: 95.39
# Epoch 70:	########################################	elapsed: 1.24s, accuracy: 95.39
# Epoch 71:	########################################	elapsed: 1.12s, accuracy: 95.39
# Epoch 72:	########################################	elapsed: 1.18s, accuracy: 95.38
# Epoch 73:	########################################	elapsed: 1.02s, accuracy: 95.39
# Epoch 74:	########################################	elapsed: 1.23s, accuracy: 95.38
# Epoch 75:	########################################	elapsed: 1.11s, accuracy: 95.38
# Epoch 76:	########################################	elapsed: 1.09s, accuracy: 95.37
# Epoch 77:	########################################	elapsed: 1.25s, accuracy: 95.37
# Epoch 78:	########################################	elapsed: 1.15s, accuracy: 95.37
# Epoch 79:	########################################	elapsed: 1.20s, accuracy: 95.37
# Epoch 80:	########################################	elapsed: 1.23s, accuracy: 95.37
# Epoch 81:	########################################	elapsed: 1.09s, accuracy: 95.37
# Epoch 82:	########################################	elapsed: 1.09s, accuracy: 95.37
# Epoch 83:	########################################	elapsed: 1.15s, accuracy: 95.37
# Epoch 84:	########################################	elapsed: 1.11s, accuracy: 95.37
# Epoch 85:	########################################	elapsed: 1.33s, accuracy: 95.37
# Epoch 86:	########################################	elapsed: 1.02s, accuracy: 95.34
# Epoch 87:	########################################	elapsed: 1.02s, accuracy: 95.34
# Epoch 88:	########################################	elapsed: 1.02s, accuracy: 95.33
# Epoch 89:	########################################	elapsed: 1.03s, accuracy: 95.33
# Epoch 90:	########################################	elapsed: 1.03s, accuracy: 95.33
# Epoch 91:	########################################	elapsed: 1.06s, accuracy: 95.31
# Epoch 92:	########################################	elapsed: 1.03s, accuracy: 95.31
# Epoch 93:	########################################	elapsed: 1.02s, accuracy: 95.30
# Epoch 94:	########################################	elapsed: 1.07s, accuracy: 95.30
# Epoch 95:	########################################	elapsed: 1.06s, accuracy: 95.30
# Epoch 96:	########################################	elapsed: 1.02s, accuracy: 95.30
# Epoch 97:	########################################	elapsed: 1.07s, accuracy: 95.29
# Epoch 98:	########################################	elapsed: 1.01s, accuracy: 95.30
# Epoch 99:	########################################	elapsed: 1.02s, accuracy: 95.29
# Epoch 100:	########################################	elapsed: 1.16s, accuracy: 95.29
# Epoch 101:	########################################	elapsed: 1.04s, accuracy: 95.28
# Epoch 102:	########################################	elapsed: 1.09s, accuracy: 95.29
# Epoch 103:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 104:	########################################	elapsed: 1.02s, accuracy: 95.29
# Epoch 105:	########################################	elapsed: 1.08s, accuracy: 95.28
# Epoch 106:	########################################	elapsed: 1.04s, accuracy: 95.27
# Epoch 107:	########################################	elapsed: 1.04s, accuracy: 95.27
# Epoch 108:	########################################	elapsed: 1.10s, accuracy: 95.27
# Epoch 109:	########################################	elapsed: 1.12s, accuracy: 95.27
# Epoch 110:	########################################	elapsed: 1.07s, accuracy: 95.27
# Epoch 111:	########################################	elapsed: 1.09s, accuracy: 95.27
# Epoch 112:	########################################	elapsed: 1.07s, accuracy: 95.27
# Epoch 113:	########################################	elapsed: 1.10s, accuracy: 95.27
# Epoch 114:	########################################	elapsed: 1.03s, accuracy: 95.27
# Epoch 115:	########################################	elapsed: 1.08s, accuracy: 95.26
# Epoch 116:	########################################	elapsed: 1.06s, accuracy: 95.26
# Epoch 117:	########################################	elapsed: 1.11s, accuracy: 95.26
# Epoch 118:	########################################	elapsed: 1.07s, accuracy: 95.26
# Epoch 119:	########################################	elapsed: 1.07s, accuracy: 95.26
# Epoch 120:	########################################	elapsed: 1.08s, accuracy: 95.26
# Epoch 121:	########################################	elapsed: 1.08s, accuracy: 95.26
# Epoch 122:	########################################	elapsed: 1.07s, accuracy: 95.26
# Epoch 123:	########################################	elapsed: 1.05s, accuracy: 95.26
# Epoch 124:	########################################	elapsed: 1.08s, accuracy: 95.26
# Epoch 125:	########################################	elapsed: 1.00s, accuracy: 95.26
# Epoch 126:	########################################	elapsed: 1.00s, accuracy: 95.26
# Epoch 127:	########################################	elapsed: 1.02s, accuracy: 95.26
# Epoch 128:	########################################	elapsed: 1.04s, accuracy: 95.27
# Epoch 129:	########################################	elapsed: 1.07s, accuracy: 95.27
# Epoch 130:	########################################	elapsed: 1.03s, accuracy: 95.27
# Epoch 131:	########################################	elapsed: 1.03s, accuracy: 95.28
# Epoch 132:	########################################	elapsed: 1.09s, accuracy: 95.28
# Epoch 133:	########################################	elapsed: 1.05s, accuracy: 95.28
# Epoch 134:	########################################	elapsed: 1.05s, accuracy: 95.28
# Epoch 135:	########################################	elapsed: 1.05s, accuracy: 95.28
# Epoch 136:	########################################	elapsed: 1.02s, accuracy: 95.29
# Epoch 137:	########################################	elapsed: 1.04s, accuracy: 95.29
# Epoch 138:	########################################	elapsed: 1.01s, accuracy: 95.29
# Epoch 139:	########################################	elapsed: 1.01s, accuracy: 95.29
# Epoch 140:	########################################	elapsed: 1.01s, accuracy: 95.30
# Epoch 141:	########################################	elapsed: 0.99s, accuracy: 95.30
# Epoch 142:	########################################	elapsed: 0.99s, accuracy: 95.30
# Epoch 143:	########################################	elapsed: 1.05s, accuracy: 95.30
# Epoch 144:	########################################	elapsed: 1.09s, accuracy: 95.30
# Epoch 145:	########################################	elapsed: 1.12s, accuracy: 95.30
# Epoch 146:	########################################	elapsed: 1.12s, accuracy: 95.30
# Epoch 147:	########################################	elapsed: 1.02s, accuracy: 95.30
# Epoch 148:	########################################	elapsed: 1.08s, accuracy: 95.30
# Epoch 149:	########################################	elapsed: 1.10s, accuracy: 95.30
# Epoch 150:	########################################	elapsed: 1.04s, accuracy: 95.30
# Epoch 151:	########################################	elapsed: 1.04s, accuracy: 95.30
# Epoch 152:	########################################	elapsed: 1.03s, accuracy: 95.30
# Epoch 153:	########################################	elapsed: 1.06s, accuracy: 95.30
# Epoch 154:	########################################	elapsed: 1.13s, accuracy: 95.30
# Epoch 155:	########################################	elapsed: 1.01s, accuracy: 95.30
# Epoch 156:	########################################	elapsed: 1.03s, accuracy: 95.30
# Epoch 157:	########################################	elapsed: 1.03s, accuracy: 95.30
# Epoch 158:	########################################	elapsed: 1.13s, accuracy: 95.30
# Epoch 159:	########################################	elapsed: 1.17s, accuracy: 95.30
# Epoch 160:	########################################	elapsed: 1.15s, accuracy: 95.30
# Epoch 161:	########################################	elapsed: 1.03s, accuracy: 95.29
# Epoch 162:	########################################	elapsed: 1.09s, accuracy: 95.29
# Epoch 163:	########################################	elapsed: 1.03s, accuracy: 95.29
# Epoch 164:	########################################	elapsed: 1.02s, accuracy: 95.29
# Epoch 165:	########################################	elapsed: 1.07s, accuracy: 95.29
# Epoch 166:	########################################	elapsed: 1.07s, accuracy: 95.29
# Epoch 167:	########################################	elapsed: 1.04s, accuracy: 95.29
# Epoch 168:	########################################	elapsed: 1.02s, accuracy: 95.29
# Epoch 169:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 170:	########################################	elapsed: 1.05s, accuracy: 95.29
# Epoch 171:	########################################	elapsed: 1.01s, accuracy: 95.29
# Epoch 172:	########################################	elapsed: 1.01s, accuracy: 95.29
# Epoch 173:	########################################	elapsed: 1.04s, accuracy: 95.29
# Epoch 174:	########################################	elapsed: 1.30s, accuracy: 95.29
# Epoch 175:	########################################	elapsed: 1.09s, accuracy: 95.29
# Epoch 176:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 177:	########################################	elapsed: 1.06s, accuracy: 95.29
# Epoch 178:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 179:	########################################	elapsed: 1.07s, accuracy: 95.29
# Epoch 180:	########################################	elapsed: 1.05s, accuracy: 95.29
# Epoch 181:	########################################	elapsed: 1.06s, accuracy: 95.29
# Epoch 182:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 183:	########################################	elapsed: 1.09s, accuracy: 95.29
# Epoch 184:	########################################	elapsed: 1.05s, accuracy: 95.29
# Epoch 185:	########################################	elapsed: 1.07s, accuracy: 95.29
# Epoch 186:	########################################	elapsed: 1.06s, accuracy: 95.29
# Epoch 187:	########################################	elapsed: 1.11s, accuracy: 95.29
# Epoch 188:	########################################	elapsed: 1.10s, accuracy: 95.29
# Epoch 189:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 190:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 191:	########################################	elapsed: 1.07s, accuracy: 95.29
# Epoch 192:	########################################	elapsed: 1.05s, accuracy: 95.29
# Epoch 193:	########################################	elapsed: 1.05s, accuracy: 95.29
# Epoch 194:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 195:	########################################	elapsed: 1.06s, accuracy: 95.29
# Epoch 196:	########################################	elapsed: 1.05s, accuracy: 95.29
# Epoch 197:	########################################	elapsed: 1.08s, accuracy: 95.29
# Epoch 198:	########################################	elapsed: 1.05s, accuracy: 95.29
# Epoch 199:	########################################	elapsed: 1.04s, accuracy: 95.29
# Epoch 200:	########################################	elapsed: 1.07s, accuracy: 95.29
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 1.00
# 	layer 2: 0.88
# 	layer 3: 4.00

# %% [markdown]
# ### MLP with dropout

# %%
mlp_with_dropout = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.2, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.5, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.5, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

evaluate(mlp_with_dropout, 
         mnist_train_images, mnist_train_labels, 
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.17s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.12s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 1.12s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 1.14s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 1.13s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 1.12s, accuracy: 11.35
# Epoch 7:	########################################	elapsed: 1.13s, accuracy: 22.44
# Epoch 8:	########################################	elapsed: 1.11s, accuracy: 58.62
# Epoch 9:	########################################	elapsed: 1.12s, accuracy: 60.94
# Epoch 10:	########################################	elapsed: 1.13s, accuracy: 74.39
# Epoch 11:	########################################	elapsed: 1.13s, accuracy: 84.36
# Epoch 12:	########################################	elapsed: 1.10s, accuracy: 78.90
# Epoch 13:	########################################	elapsed: 1.12s, accuracy: 88.67
# Epoch 14:	########################################	elapsed: 1.14s, accuracy: 88.81
# Epoch 15:	########################################	elapsed: 1.28s, accuracy: 90.46
# Epoch 16:	########################################	elapsed: 1.15s, accuracy: 91.39
# Epoch 17:	########################################	elapsed: 1.14s, accuracy: 91.73
# Epoch 18:	########################################	elapsed: 1.10s, accuracy: 91.78
# Epoch 19:	########################################	elapsed: 1.11s, accuracy: 92.45
# Epoch 20:	########################################	elapsed: 1.13s, accuracy: 93.02
# Epoch 21:	########################################	elapsed: 1.10s, accuracy: 92.72
# Epoch 22:	########################################	elapsed: 1.12s, accuracy: 90.44
# Epoch 23:	########################################	elapsed: 1.14s, accuracy: 91.99
# Epoch 24:	########################################	elapsed: 1.12s, accuracy: 93.50
# Epoch 25:	########################################	elapsed: 1.12s, accuracy: 93.86
# Epoch 26:	########################################	elapsed: 1.19s, accuracy: 91.99
# Epoch 27:	########################################	elapsed: 1.26s, accuracy: 93.56
# Epoch 28:	########################################	elapsed: 1.13s, accuracy: 93.63
# Epoch 29:	########################################	elapsed: 1.13s, accuracy: 91.86
# Epoch 30:	########################################	elapsed: 1.11s, accuracy: 92.89
# Epoch 31:	########################################	elapsed: 1.11s, accuracy: 93.79
# Epoch 32:	########################################	elapsed: 1.14s, accuracy: 93.81
# Epoch 33:	########################################	elapsed: 1.18s, accuracy: 93.40
# Epoch 34:	########################################	elapsed: 1.16s, accuracy: 93.71
# Epoch 35:	########################################	elapsed: 1.15s, accuracy: 94.08
# Epoch 36:	########################################	elapsed: 1.15s, accuracy: 94.19
# Epoch 37:	########################################	elapsed: 1.11s, accuracy: 92.88
# Epoch 38:	########################################	elapsed: 1.12s, accuracy: 94.26
# Epoch 39:	########################################	elapsed: 1.14s, accuracy: 94.47
# Epoch 40:	########################################	elapsed: 1.10s, accuracy: 94.62
# Epoch 41:	########################################	elapsed: 1.11s, accuracy: 94.29
# Epoch 42:	########################################	elapsed: 1.13s, accuracy: 94.96
# Epoch 43:	########################################	elapsed: 1.13s, accuracy: 94.94
# Epoch 44:	########################################	elapsed: 1.18s, accuracy: 94.48
# Epoch 45:	########################################	elapsed: 1.16s, accuracy: 95.08
# Epoch 46:	########################################	elapsed: 1.14s, accuracy: 94.70
# Epoch 47:	########################################	elapsed: 1.14s, accuracy: 94.88
# Epoch 48:	########################################	elapsed: 1.17s, accuracy: 95.08
# Epoch 49:	########################################	elapsed: 1.21s, accuracy: 95.11
# Epoch 50:	########################################	elapsed: 1.26s, accuracy: 95.02
# Epoch 51:	########################################	elapsed: 1.46s, accuracy: 94.83
# Epoch 52:	########################################	elapsed: 1.33s, accuracy: 94.68
# Epoch 53:	########################################	elapsed: 1.25s, accuracy: 94.49
# Epoch 54:	########################################	elapsed: 1.22s, accuracy: 95.34
# Epoch 55:	########################################	elapsed: 1.28s, accuracy: 94.70
# Epoch 56:	########################################	elapsed: 1.21s, accuracy: 94.97
# Epoch 57:	########################################	elapsed: 1.24s, accuracy: 95.33
# Epoch 58:	########################################	elapsed: 1.22s, accuracy: 94.87
# Epoch 59:	########################################	elapsed: 1.26s, accuracy: 95.39
# Epoch 60:	########################################	elapsed: 1.22s, accuracy: 95.21
# Epoch 61:	########################################	elapsed: 1.40s, accuracy: 95.35
# Epoch 62:	########################################	elapsed: 1.33s, accuracy: 94.64
# Epoch 63:	########################################	elapsed: 1.25s, accuracy: 95.00
# Epoch 64:	########################################	elapsed: 1.24s, accuracy: 95.15
# Epoch 65:	########################################	elapsed: 1.25s, accuracy: 95.25
# Epoch 66:	########################################	elapsed: 1.22s, accuracy: 95.20
# Epoch 67:	########################################	elapsed: 1.24s, accuracy: 95.55
# Epoch 68:	########################################	elapsed: 1.22s, accuracy: 95.35
# Epoch 69:	########################################	elapsed: 1.27s, accuracy: 95.42
# Epoch 70:	########################################	elapsed: 1.22s, accuracy: 95.16
# Epoch 71:	########################################	elapsed: 1.23s, accuracy: 94.82
# Epoch 72:	########################################	elapsed: 1.22s, accuracy: 95.21
# Epoch 73:	########################################	elapsed: 1.25s, accuracy: 95.11
# Epoch 74:	########################################	elapsed: 1.23s, accuracy: 95.17
# Epoch 75:	########################################	elapsed: 1.21s, accuracy: 95.68
# Epoch 76:	########################################	elapsed: 1.25s, accuracy: 94.89
# Epoch 77:	########################################	elapsed: 1.24s, accuracy: 95.20
# Epoch 78:	########################################	elapsed: 1.23s, accuracy: 95.06
# Epoch 79:	########################################	elapsed: 1.23s, accuracy: 95.58
# Epoch 80:	########################################	elapsed: 1.26s, accuracy: 95.09
# Epoch 81:	########################################	elapsed: 1.25s, accuracy: 94.88
# Epoch 82:	########################################	elapsed: 1.21s, accuracy: 95.85
# Epoch 83:	########################################	elapsed: 1.23s, accuracy: 95.56
# Epoch 84:	########################################	elapsed: 1.25s, accuracy: 95.54
# Epoch 85:	########################################	elapsed: 1.22s, accuracy: 95.44
# Epoch 86:	########################################	elapsed: 1.23s, accuracy: 95.65
# Epoch 87:	########################################	elapsed: 1.25s, accuracy: 95.40
# Epoch 88:	########################################	elapsed: 1.25s, accuracy: 95.77
# Epoch 89:	########################################	elapsed: 1.22s, accuracy: 95.43
# Epoch 90:	########################################	elapsed: 1.22s, accuracy: 95.28
# Epoch 91:	########################################	elapsed: 1.25s, accuracy: 95.54
# Epoch 92:	########################################	elapsed: 1.26s, accuracy: 95.45
# Epoch 93:	########################################	elapsed: 1.22s, accuracy: 95.59
# Epoch 94:	########################################	elapsed: 1.23s, accuracy: 95.33
# Epoch 95:	########################################	elapsed: 1.26s, accuracy: 95.58
# Epoch 96:	########################################	elapsed: 1.23s, accuracy: 95.82
# Epoch 97:	########################################	elapsed: 1.23s, accuracy: 95.51
# Epoch 98:	########################################	elapsed: 1.24s, accuracy: 94.99
# Epoch 99:	########################################	elapsed: 1.25s, accuracy: 95.54
# Epoch 100:	########################################	elapsed: 1.23s, accuracy: 95.41
# Epoch 101:	########################################	elapsed: 1.21s, accuracy: 95.72
# Epoch 102:	########################################	elapsed: 1.23s, accuracy: 95.62
# Epoch 103:	########################################	elapsed: 1.23s, accuracy: 95.53
# Epoch 104:	########################################	elapsed: 1.22s, accuracy: 95.84
# Epoch 105:	########################################	elapsed: 1.22s, accuracy: 95.74
# Epoch 106:	########################################	elapsed: 1.24s, accuracy: 95.56
# Epoch 107:	########################################	elapsed: 1.24s, accuracy: 95.81
# Epoch 108:	########################################	elapsed: 1.22s, accuracy: 95.46
# Epoch 109:	########################################	elapsed: 1.21s, accuracy: 95.87
# Epoch 110:	########################################	elapsed: 1.27s, accuracy: 95.88
# Epoch 111:	########################################	elapsed: 1.21s, accuracy: 95.66
# Epoch 112:	########################################	elapsed: 1.21s, accuracy: 95.82
# Epoch 113:	########################################	elapsed: 1.23s, accuracy: 95.85
# Epoch 114:	########################################	elapsed: 1.25s, accuracy: 95.77
# Epoch 115:	########################################	elapsed: 1.21s, accuracy: 95.36
# Epoch 116:	########################################	elapsed: 1.21s, accuracy: 95.61
# Epoch 117:	########################################	elapsed: 1.25s, accuracy: 95.65
# Epoch 118:	########################################	elapsed: 1.23s, accuracy: 95.60
# Epoch 119:	########################################	elapsed: 1.22s, accuracy: 95.91
# Epoch 120:	########################################	elapsed: 1.21s, accuracy: 95.08
# Epoch 121:	########################################	elapsed: 1.24s, accuracy: 95.66
# Epoch 122:	########################################	elapsed: 1.22s, accuracy: 95.68
# Epoch 123:	########################################	elapsed: 1.21s, accuracy: 95.70
# Epoch 124:	########################################	elapsed: 1.22s, accuracy: 95.76
# Epoch 125:	########################################	elapsed: 1.24s, accuracy: 96.13
# Epoch 126:	########################################	elapsed: 1.22s, accuracy: 95.95
# Epoch 127:	########################################	elapsed: 1.22s, accuracy: 95.92
# Epoch 128:	########################################	elapsed: 1.25s, accuracy: 95.93
# Epoch 129:	########################################	elapsed: 1.23s, accuracy: 96.08
# Epoch 130:	########################################	elapsed: 1.22s, accuracy: 95.47
# Epoch 131:	########################################	elapsed: 1.22s, accuracy: 95.82
# Epoch 132:	########################################	elapsed: 1.25s, accuracy: 95.60
# Epoch 133:	########################################	elapsed: 1.22s, accuracy: 95.47
# Epoch 134:	########################################	elapsed: 1.23s, accuracy: 95.36
# Epoch 135:	########################################	elapsed: 1.40s, accuracy: 95.43
# Epoch 136:	########################################	elapsed: 1.26s, accuracy: 95.26
# Epoch 137:	########################################	elapsed: 1.24s, accuracy: 95.96
# Epoch 138:	########################################	elapsed: 1.23s, accuracy: 95.69
# Epoch 139:	########################################	elapsed: 1.23s, accuracy: 95.51
# Epoch 140:	########################################	elapsed: 1.25s, accuracy: 95.54
# Epoch 141:	########################################	elapsed: 1.23s, accuracy: 95.20
# Epoch 142:	########################################	elapsed: 1.30s, accuracy: 95.18
# Epoch 143:	########################################	elapsed: 1.27s, accuracy: 95.60
# Epoch 144:	########################################	elapsed: 1.26s, accuracy: 95.27
# Epoch 145:	########################################	elapsed: 1.24s, accuracy: 95.63
# Epoch 146:	########################################	elapsed: 1.38s, accuracy: 95.68
# Epoch 147:	########################################	elapsed: 1.26s, accuracy: 95.65
# Epoch 148:	########################################	elapsed: 1.26s, accuracy: 95.79
# Epoch 149:	########################################	elapsed: 1.24s, accuracy: 95.57
# Epoch 150:	########################################	elapsed: 1.24s, accuracy: 95.67
# Epoch 151:	########################################	elapsed: 1.27s, accuracy: 95.24
# Epoch 152:	########################################	elapsed: 1.26s, accuracy: 95.57
# Epoch 153:	########################################	elapsed: 1.23s, accuracy: 95.37
# Epoch 154:	########################################	elapsed: 1.23s, accuracy: 95.76
# Epoch 155:	########################################	elapsed: 1.34s, accuracy: 95.91
# Epoch 156:	########################################	elapsed: 1.27s, accuracy: 95.80
# Epoch 157:	########################################	elapsed: 1.23s, accuracy: 95.91
# Epoch 158:	########################################	elapsed: 1.23s, accuracy: 95.18
# Epoch 159:	########################################	elapsed: 1.24s, accuracy: 95.77
# Epoch 160:	########################################	elapsed: 1.26s, accuracy: 95.19
# Epoch 161:	########################################	elapsed: 1.24s, accuracy: 95.87
# Epoch 162:	########################################	elapsed: 1.24s, accuracy: 95.98
# Epoch 163:	########################################	elapsed: 1.32s, accuracy: 96.08
# Epoch 164:	########################################	elapsed: 1.26s, accuracy: 95.45
# Epoch 165:	########################################	elapsed: 1.23s, accuracy: 95.93
# Epoch 166:	########################################	elapsed: 1.24s, accuracy: 95.44
# Epoch 167:	########################################	elapsed: 1.25s, accuracy: 95.80
# Epoch 168:	########################################	elapsed: 1.26s, accuracy: 95.56
# Epoch 169:	########################################	elapsed: 1.23s, accuracy: 95.71
# Epoch 170:	########################################	elapsed: 1.23s, accuracy: 95.61
# Epoch 171:	########################################	elapsed: 1.15s, accuracy: 96.03
# Epoch 172:	########################################	elapsed: 1.12s, accuracy: 96.09
# Epoch 173:	########################################	elapsed: 1.14s, accuracy: 96.30
# Epoch 174:	########################################	elapsed: 1.14s, accuracy: 96.16
# Epoch 175:	########################################	elapsed: 1.13s, accuracy: 96.12
# Epoch 176:	########################################	elapsed: 1.11s, accuracy: 96.06
# Epoch 177:	########################################	elapsed: 1.21s, accuracy: 96.15
# Epoch 178:	########################################	elapsed: 1.17s, accuracy: 96.18
# Epoch 179:	########################################	elapsed: 1.11s, accuracy: 96.15
# Epoch 180:	########################################	elapsed: 1.14s, accuracy: 96.19
# Epoch 181:	########################################	elapsed: 1.13s, accuracy: 96.32
# Epoch 182:	########################################	elapsed: 1.12s, accuracy: 96.22
# Epoch 183:	########################################	elapsed: 1.13s, accuracy: 96.21
# Epoch 184:	########################################	elapsed: 1.14s, accuracy: 96.29
# Epoch 185:	########################################	elapsed: 1.11s, accuracy: 96.23
# Epoch 186:	########################################	elapsed: 1.13s, accuracy: 96.26
# Epoch 187:	########################################	elapsed: 1.15s, accuracy: 96.22
# Epoch 188:	########################################	elapsed: 1.17s, accuracy: 96.22
# Epoch 189:	########################################	elapsed: 1.13s, accuracy: 96.29
# Epoch 190:	########################################	elapsed: 1.15s, accuracy: 96.36
# Epoch 191:	########################################	elapsed: 1.12s, accuracy: 96.33
# Epoch 192:	########################################	elapsed: 1.12s, accuracy: 96.18
# Epoch 193:	########################################	elapsed: 1.14s, accuracy: 96.36
# Epoch 194:	########################################	elapsed: 1.14s, accuracy: 96.33
# Epoch 195:	########################################	elapsed: 1.10s, accuracy: 96.32
# Epoch 196:	########################################	elapsed: 1.13s, accuracy: 96.33
# Epoch 197:	########################################	elapsed: 1.17s, accuracy: 96.34
# Epoch 198:	########################################	elapsed: 1.13s, accuracy: 96.29
# Epoch 199:	########################################	elapsed: 1.13s, accuracy: 96.27
# Epoch 200:	########################################	elapsed: 1.12s, accuracy: 96.30
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 1.00
# 	layer 2: 1.00
# 	layer 3: 4.00
